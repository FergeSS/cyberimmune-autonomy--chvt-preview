# %% [markdown]
# # Кибериммунная автономность$\\$Создание конструктивно защищённого автономного наземного транспортного средства$\\$Модуль 3
#
# ## О документе
#
# Версия 1.03
#
# Модуль 3 для регионального этапа соревнований по кибериммунной автономности

# %% [markdown]
# ### Модуль 3. Внедрение блоков функциональной и информационной безопасности
# #### Общая идея
#
# Ключевая идея кибериммунной автономности заключается в том, чтобы уже на этапе проектирования внедрить защиту от кибератак как снаружи, так и изнутри - т.е. через уязвимые бортовые информационные системы.
# Мы исходим из того, что абсолютно защищённых систем не бывает, чем больше и сложнее код, тем проще одним ("плохим") в нём спрятать уязвимости, а другим ("хорошим", но уставшим) эти уязвимости не найти.
#
# Поэтому необходимо сделать так, чтобы наиболее критичный код был отделён от некритичного и протестирован особенно тщательно - таким образом можно снизить вероятность успешной атаки и затруднить задачу атакующим.

# %% [markdown]
# #### Цели и предположения безопасности
#
# ##### Цели безопасности
# Устойчивость кибериммунных систем к атакам выражается в том, что поставленные заказчиком **цели безопасности** (ЦБ) не нарушаются даже в условиях кибератак (снаружи и изнутри).
#
# Для наших автономных машинок заказчиком поставлены следующие ЦБ:
#
# 1. При любых обстоятельствах АНТС осуществляет перемещения в пределах заданных ограничений
#
# 2. При любых обстоятельствах АНТС выполняет только аутентичный (подлинный) маршрут
#
# 3. При любых обстоятельствах АНТС оставляет груз только в авторизованном пункте назначения
#
# Ниже используется цифро-буквенное обозначение целей безопасности - например, ЦБ1 - первая цель безопасности из списка выше.
#
# ##### Предположения безопасности
# При этом заказчик согласовал с разработчиками следующие **предположения безопасности** (ПБ) - утверждения о смежных системах, которые снимают с разработчиков часть задач для обеспечения целей безопасности:
#
# 1. При любых обстоятельствах только авторизованный персонал имеет физический доступ к критическим узлам АНТС
#
# 2. При любых обстоятельствах только аутентичные и авторизованные операторы имеют доступ к системе планирования заданий
#
# 3. Аутентичные и авторизованные операторы обладают необходимой квалификацией и являются благонадёжными (т.е. не пытаются намеренно причинить ущерб системе или третьим лицам, используя доступ к АНТС)
#
# Ниже используется цифро-буквенное обозначение предположений безопасности - например, ПБ1 - первое предположение безопасности из списка выше.

# %% [markdown]
# ### Киберпрепятствия
#
# Прежде чем мы начнём внедрять механизмы безопасности, посмотрим, что произойдёт с нашей машинкой, если бортовые системы начнут вести себя не так, как мы ожидаем.
#
# Для этого активируем специальный режим работы системы управления и снова запустим машинку по тому же маршруту, который был в конце модуля 2.
#
# После инициализации системы управления добавьте следующую строку
# ```python
# control_system.enable_surprises()
# ```

# %% [markdown]
# Но вначале нужно из модуля 2 скопировать сюда ваши текущие наработки, а именно ваши реализации классов коммуникационного шлюза (CommunicationGateway), систему навигации (NavigationSystem), управления (ControlSystem), также будем использовать маршрут, который вы создали.

# %%
# вставьте сюда ваш код
# ваш код
from multiprocessing import Queue

from src.config import CONTROL_SYSTEM_QUEUE_NAME
from src.config import SERVOS_QUEUE_NAME
from src.config import CONTROL_SYSTEM_QUEUE_NAME

from src.navigation_system import BaseNavigationSystem
from src.communication_gateway import BaseCommunicationGateway
from src.control_system import BaseControlSystem
from src.event_types import Event

class CommunicationGateway(BaseCommunicationGateway):
    """CommunicationGateway класс для реализации логики взаимодействия
    с системой планирования заданий

    Работает в отдельном процессе, поэтому создаётся как наследник класса Process
    """
    def _send_mission_to_consumers(self):
        """ метод для отправки сообщения с маршрутным заданием в систему управления """
        
        # имена очередей блоков находятся в файле src/config.py
        # события нужно отправлять в соответствие с диаграммой информационных потоков
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME

        # события передаются в виде экземпляров класса Event, 
        # описание класса находится в файле src/event_types.py
        event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=control_q_name,
                      operation="set_mission", parameters=self._mission
                      )

        # поиск в каталоге нужной очереди (в данном случае - системы управления)
        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        # отправка события в найденную очередь
        control_q.put(event)

class ControlSystem(BaseControlSystem):
    """ControlSystem блок расчёта управления """

    def _send_speed_and_direction_to_consumers(self, speed, direction):
        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=BaseControlSystem.event_source_name,
                            destination=servos_q_name,
                            operation="set_speed",
                            parameters=speed
                            )
        # отправка сообщения с желаемым направлением
        event_direction = Event(source=BaseControlSystem.event_source_name,
                                destination=servos_q_name,
                                operation="set_direction",
                                parameters=direction
                                )

        servos_q.put(event_speed)
        servos_q.put(event_direction)   

class NavigationSystem(BaseNavigationSystem):
    """ класс навигационного блока """
    def _send_position_to_consumers(self):        
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME
        event = Event(source=BaseNavigationSystem.event_source_name,
                      destination=control_q_name,
                      operation="position_update",
                      parameters=self._position
                      )
        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        control_q.put(event)

# %% [markdown]
# Если у вас настроена и работает СУПА, установите в True значение переменной afcs_present

# %%
afcs_present = True

# %% [markdown]
# Поменяем идентификатор машинки для этого модуля

# %%
car_id = "m3"

# %%
# используем то же маршрутное задание, которое было в модуле 2
from time import sleep
from geopy import Point as GeoPoint


from src.queues_dir import QueuesDirectory
from src.servos import Servos
from src.sitl import SITL
from src.cargo_bay import CargoBay
from src.mission_planner import MissionPlanner
from src.config import LOG_ERROR, LOG_INFO
from src.mission_planner_mqtt import MissionSender
from src.mission_planner import Mission
from src.sitl_mqtt import TelemetrySender
from src.system_wrapper import SystemComponentsContainer
from src.wpl_parser import WPLParser


# возьмём маршрут из модуля 2
wpl_file = "module2.wpl"

parser = WPLParser(wpl_file)    
points = parser.parse()
print(points)

from src.mission_type import GeoSpecificSpeedLimit
speed_limits = [
    GeoSpecificSpeedLimit(0, 50),
    GeoSpecificSpeedLimit(1, 20),
    GeoSpecificSpeedLimit(2, 60),
    GeoSpecificSpeedLimit(3, 20),
    GeoSpecificSpeedLimit(4, 60),
    GeoSpecificSpeedLimit(5, 40),
    GeoSpecificSpeedLimit(6, 30),
    GeoSpecificSpeedLimit(7, 60),
    GeoSpecificSpeedLimit(8, 30),
    GeoSpecificSpeedLimit(9, 40),
    GeoSpecificSpeedLimit(10, 20),
    GeoSpecificSpeedLimit(11, 20),
    GeoSpecificSpeedLimit(12, 40),
    GeoSpecificSpeedLimit(13, 20),
    GeoSpecificSpeedLimit(14, 50),
]


home = points[0]
mission = Mission(home=home, waypoints=points,speed_limits=speed_limits, armed=True)

# каталог очередей для передачи сообщений между блоками
queues_dir = QueuesDirectory() 

if afcs_present:
    mission_sender = MissionSender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)
    telemetry_sender = TelemetrySender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)

mission_planner = MissionPlanner(
    queues_dir, afcs_present=afcs_present, mission=mission)

sitl = SITL(
    queues_dir=queues_dir, position=home,
    car_id=car_id, post_telemetry=afcs_present, log_level=LOG_ERROR)

communication_gateway = CommunicationGateway(
    queues_dir=queues_dir, log_level=LOG_ERROR)
control_system = ControlSystem(queues_dir=queues_dir, log_level=LOG_INFO)

navigation_system = NavigationSystem(
    queues_dir=queues_dir, log_level=LOG_ERROR)

servos = Servos(queues_dir=queues_dir, log_level=LOG_ERROR)
cargo_bay = CargoBay(queues_dir=queues_dir, log_level=LOG_INFO)

# по аналогии собираем все блоки в одном кузове
system_components = SystemComponentsContainer(
    components=[
        mission_sender,
        telemetry_sender,
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system
    ] if afcs_present else [
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system
    ])

#################################
# АКТИВАЦИЯ КИБЕРПРЕПЯТСТВИЙ
control_system.enable_surprises()
#################################

system_components.start()

# ограничение поездки по времени
# параметр sleep - время в секундах,
# настройте этот параметр так, чтобы ваша машинка завершила маршрут
# в случае превышения времени выполнения ячейки на более чем 10 секунд от заданного, 
# допустимо перезапустить вычислительное ядро и повторно выполнить весь блокнот, штрафные очки за это не начисляются
# при условии, что повторный запуск закончился успешно
sleep(1)

# останавливаем все компоненты
system_components.stop()

# удалим все созданные компоненты
system_components.clean()
del system_components
# Out:
# [Point(59.927085760656304, 30.339722531511693, 0.0), Point(59.926292180395535, 30.342233217591005, 0.0), Point(59.926173699944215, 30.34242633664008, 0.0), Point(59.92209171270232, 30.332035318339557, 0.0), Point(59.92200822727937, 30.331826106036402, 0.0), Point(59.924914940966076, 30.32745676097576, 0.0), Point(59.925423884727905, 30.32667892036145, 0.0), Point(59.92558545253803, 30.326394606205874, 0.0), Point(59.93032701710794, 30.319320571688525, 0.0), Point(59.93055856305187, 30.318969202307596, 0.0), Point(59.929748021505674, 30.316205517732527, 0.0), Point(59.92969417243625, 30.31602849193753, 0.0), Point(59.929621476053455, 30.315948025667083, 0.0), Point(59.929018359158015, 30.31544913479032, 0.0), Point(59.92887027073796, 30.315379397355926, 0.0), Point(59.92945185053862, 30.314794675790694, 0.0)]
# [ИНФО][QUEUES] создан каталог очередей
# [ИНФО][QUEUES] регистрируем очередь planner.mqtt
# [ИНФО][QUEUES] регистрируем очередь sitl.mqtt
# [ИНФО][QUEUES] регистрируем очередь planner
# [ИНФО][MISSION PLANNER] создана система планирования заданий
# [ИНФО][QUEUES] регистрируем очередь sitl
# [ИНФО][QUEUES] регистрируем очередь communication
# [ИНФО][QUEUES] регистрируем очередь control
# [ИНФО][CONTROL] создана система управления
# [ИНФО][QUEUES] регистрируем очередь navigation
# [ИНФО][QUEUES] регистрируем очередь servos
# [ИНФО][QUEUES] регистрируем очередь cargo
# [ИНФО][CARGO] создан компонент грузового отсека, отсек заблокирован
# [ИНФО][MISSION PLANNER] старт системы планирования заданий
# [ИНФО][CARGO] старт блока грузового отсека
# [ИНФО][CONTROL] старт системы управления
# [ИНФО][MISSION PLANNER] запрошена новая задача, отправляем получателям
# [ИНФО][MISSION PLANNER] новая задача отправлена в коммуникационный шлюз
# [ИНФО][CONTROL] установлена новая задача, начинаем следовать по маршруту, текущее время 12:07:17.954903
# [ИНФО][CONTROL] новая скорость 50 (была 0)
# [ИНФО][CONTROL] новое направление 122 (было 0)

# %% [markdown]
# Итак, в отличие от, надеемся, успешного завершения маршрута в модуле 2, сейчас ваша машинка ведёт себя совсем иначе. Например, она внезапно едет в совершенно другую сторону (это особенно хорошо видно при использовании СУПА).
# И это ещё не всё, что может пойти не так..
#
# В этой реализации не очень много кода, теоретически, вы можете его весь изучить и устранить "незадокументированные возможности", однако в реальных системах кода гораздо больше. Например, кодовая база проекта с открытым исходным кодом ArduPilot, реализующего в том числе логику автопилота, составляет примерно миллион строк.
#
# Сколько времени вам понадобится, чтобы изучить и протестировать миллион строк кода? А ведь придётся проводить анализ и каждого обновления.. При этом неприятности могут быть хорошо спрятанными и на первый взгляд безобидными, вряд ли злоумышленники облегчат задачу и назовут свои изменения, например, "hacking_the_system" или "allowing_secret_remote_access". Вредоносный код может выглядеть совершенно безобидно или маскироваться под программный дефект.
#
# Поэтому тщательный анализ потребует большого количества ресурсов (человеческих, вычислительных, временныз), что стоит дорого.
#
# Логичным выходом является выделение критичных для целей безопасности проверок в отдельный блок, который протестировать должно быть гораздо проще.

# %% [markdown]
# #### Задания
#
# В этом модуле задание будет состоять из двух частей разной сложности:
#
# **3.1. добавить новый блок - "Ограничитель"** - этот модуль должен будет обеспечить соблюдение ограничений, указанных в маршрутном задании - это необходимо для обеспечения ЦБ1
#
# **З.2. *(задание повышенной сложности)* добавить монитор безопасности (МБ)** - он должен контролировать все взаимодействия *бортовых систем* (т.е. не включая планировщик и симулятор) и не давать блокам взаимодействовать друг с другом непредусмотренным образом - например, блок №5 может принимать команды только от №3, попытка передать команду в №5 от №2 должна блокироваться нашим монитором безопасности - потенциально это необходимо для обеспечения всех ЦБ

# %% [markdown]
# Для выполнения первой части задачи 3.1. необходимо для начала изменить архитектуру АНТС как показано на рис. 5
#
# ![Архитектура системы с ограничителем](images/ciac-arch-m31.png)
#
# Рис. 5. Архитектура АНТС с ограничителем (для ЦБ1)

# %% [markdown]
# Код базового класса Ограничителя находится в файле src/safety_block.py
#
# По аналогии с заданием в модуле 1, необходимо создать на основе этого класса свой собственный под названием SafetyBlock, в котором реализовать передачу команд в приводы движения, только перед эти необходимо ещё и проконтролировать их безопасность.
#
# Также необходимо реализовать передачу маршрутного задания из CommunicationGateway в SafetyBlock и координат из модуля Navigation в соответствии со стрелками на рис.5 выше.
#
# Если всё сделано правильно, то Ограничителю будет известно следующее
#
# - _mission - текущее маршрутное задание
# - _position - текущие координаты
#
# После проверки нужно установить значение внутренних переменных
# - _speed - текущая (допустимая) скорость
# - _direction - текущее (допустимое) направление
#
# Желательно завершить следование по маршруту. В критической ситуации, если продолжение маршрута невозможно, следует установить значение скорости и направления в 0, после чего передать эти команды в блок приводов (Servos)

# %% [markdown]
# Базовый сценарий для новой архитектуры можно представить следующим образом (см. рис. 6)
#
# ![Базовый сценарий с блоком безопасности](images/basic-scenario-with-safety-block1.png)
#
# Рис. 6. Базовый сценарий с блоком безопасности

# %% [markdown]
# Заготовка кода SafetyBlock
#
# ```python
# class SafetyBlock(BaseSafetyBlock):
#     """ класс ограничений безопасности """
#
#     def _set_new_direction(self, direction: float):
#         """ установка нового направления перемещения """
#         self._log_message(LOG_INFO, f"текущие координаты: {self._position}")
#         self._log_message(LOG_DEBUG, f"маршрутное задание: {self._mission}")
#         self._log_message(LOG_DEBUG, f"состояние маршруте: {self._route}")
#         # TODO реализовать контроль безопасности изменения направления
#         self._direction = direction
#         self._send_direction_to_consumers()
#
#     def _set_new_speed(self, speed: float):
#         """ установка новой скорости """
#         # TODO реализовать контроль безопасности изменения скорости
#         self._speed = speed
#         self._send_speed_to_consumers()
#
#
#     def _send_speed_to_consumers(self):
#         self._log_message(LOG_DEBUG, "отправляем скорость получателям")
#         servos_q_name = SERVOS_QUEUE_NAME
#         servos_q: Queue = self._queues_dir.get_queue(servos_q_name)
#
#         # отправка сообщения с желаемой скоростью
#         event_speed = Event(source=self.event_source_name,
#                             destination=servos_q_name,
#                             operation="set_speed",
#                             parameters=self._speed
#                             )
#         servos_q.put(event_speed)
#
#     def _send_direction_to_consumers(self):
#         self._log_message(LOG_DEBUG, "отправляем направление получателям")
#
#         servos_q_name = SERVOS_QUEUE_NAME
#         servos_q: Queue = self._queues_dir.get_queue(servos_q_name)
#
#         # отправка сообщения с желаемой скоростью
#         event_speed = Event(source=self.event_source_name,
#                             destination=servos_q_name,
#                             operation="set_direction",
#                             parameters=self._direction
#                             )
#         servos_q.put(event_speed)
# ```

# %%
from src.safety_block import BaseSafetyBlock
from src.config import LOG_DEBUG
import math

class SafetyBlock(BaseSafetyBlock):
    """ класс ограничений безопасности """

    def _set_new_direction(self, direction: float):
        """ установка нового направления перемещения """

        self._log_message(LOG_INFO, f"текущие координаты: {self._position}")
        self._log_message(LOG_DEBUG, f"маршрутное задание: {self._mission}")
        self._log_message(LOG_DEBUG, f"состояние маршруте: {self._route}")
        # TODO реализовать контроль безопасности изменения направления
        target_point = self._route.next_point()
        current_point = self._position
        target_direction = self._calculate_bearing(current_point, target_point)
        if not self._mission or not self._position or not self._route:
            self._log_message(LOG_ERROR, f"Неизвестный маршрут или позиция! Остановка.")
            self._direction = 0
            self._speed = 0
            self._send_direction_to_consumers()
            self._send_speed_to_consumers()
            return

        if abs(direction - target_direction) > 1:  # Допустимое отклонение 1 градус
            self._log_message(LOG_ERROR, f"Некорректное направление! Запрошено: {direction}, ожидалось: {target_direction}")
            self._direction = target_direction
            self._send_direction_to_consumers()
            return  
        
        self._direction = direction
        self._send_direction_to_consumers()

    def _set_new_speed(self, speed: float):
        """ установка новой скорости """
        # TODO реализовать контроль безопасности изменения скорости
        current_limit = self._route.calculate_speed()

        if not self._mission or not self._position or not self._route:
            self._log_message(LOG_ERROR, f"Неизвестный маршрут или позиция! Остановка.")
            self._direction = 0
            self._speed = 0
            self._send_direction_to_consumers()
            self._send_speed_to_consumers()
            return
        
        if speed > current_limit:
            self._log_message(LOG_ERROR, f"Превышение скорости! Лимит: {current_limit}, запрошено: {speed}")
            self._speed = current_limit
        else:
            self._speed = speed
        
        self._send_speed_to_consumers()
        self._send_direction_to_consumers()
    
    def _calculate_bearing(self, start: GeoPoint, end: GeoPoint) -> float:
        delta_longitude = end.longitude - start.longitude
        x = math.sin(math.radians(delta_longitude)) * \
            math.cos(math.radians(end.latitude))
        y = math.cos(math.radians(start.latitude)) * math.sin(math.radians(end.latitude)) - \
            math.sin(math.radians(start.latitude)) * math.cos(math.radians(end.latitude)) * \
            math.cos(math.radians(delta_longitude))

        initial_bearing_rad = math.atan2(x, y)

        initial_bearing_deg = math.degrees(initial_bearing_rad)

        compass_bearing = (initial_bearing_deg + 360) % 360

        return compass_bearing


    def _send_speed_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем скорость получателям")
        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_speed",
                            parameters=self._speed
                            )
        servos_q.put(event_speed)

    def _send_direction_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем направление получателям")

        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_direction",
                            parameters=self._direction
                            )
        servos_q.put(event_speed)

# %%
# 2. напишите в этом блоке реализацию изменённых блоков связи, управления и навигации, 
# чтобы передавать данные согласно изменённой архитектуре на рис. 5 для обеспечения работы по сценарию на рис.6

from multiprocessing import Queue

from src.config import CONTROL_SYSTEM_QUEUE_NAME
from src.config import SERVOS_QUEUE_NAME
from src.config import CONTROL_SYSTEM_QUEUE_NAME

from src.config import SAFETY_BLOCK_QUEUE_NAME

from src.navigation_system import BaseNavigationSystem
from src.communication_gateway import BaseCommunicationGateway
from src.control_system import BaseControlSystem
from src.event_types import Event

class CommunicationGateway(BaseCommunicationGateway):
    """CommunicationGateway класс для реализации логики взаимодействия
    с системой планирования заданий

    Работает в отдельном процессе, поэтому создаётся как наследник класса Process
    """
    def _send_mission_to_consumers(self):
        """ метод для отправки сообщения с маршрутным заданием в систему управления """
        
        # имена очередей блоков находятся в файле src/config.py
        # события нужно отправлять в соответствие с диаграммой информационных потоков
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME

        # события передаются в виде экземпляров класса Event, 
        # описание класса находится в файле src/event_types.py
        event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=control_q_name,
                      operation="set_mission", 
                      parameters=self._mission
                      )

        # поиск в каталоге нужной очереди (в данном случае - системы управления)
        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        # отправка события в найденную очередь
        control_q.put(event)

        safety_q_name = SAFETY_BLOCK_QUEUE_NAME
        event = Event(
            source=BaseCommunicationGateway.event_source_name,
            destination=safety_q_name,
            operation="set_mission",
            parameters=self._mission
        )
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        safety_q.put(event)

class ControlSystem(BaseControlSystem):
    """ControlSystem блок расчёта управления """

    def _send_speed_and_direction_to_consumers(self, speed, direction):
        # servos_q_name = SERVOS_QUEUE_NAME
        # servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        # # отправка сообщения с желаемой скоростью
        # event_speed = Event(source=BaseControlSystem.event_source_name,
        #                     destination=servos_q_name,
        #                     operation="set_speed",
        #                     parameters=speed
        #                     )
        # # отправка сообщения с желаемым направлением
        # event_direction = Event(source=BaseControlSystem.event_source_name,
        #                         destination=servos_q_name,
        #                         operation="set_direction",
        #                         parameters=direction
        #                         )

        # servos_q.put(event_speed)
        # servos_q.put(event_direction)
        
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        
        event_speed = Event(
            source=BaseControlSystem.event_source_name,
            destination=safety_q_name,
            operation="set_speed",
            parameters=speed
        )
        event_direction = Event(
            source=BaseControlSystem.event_source_name,
            destination=safety_q_name,
            operation="set_direction",
            parameters=direction
        )
        safety_q.put(event_speed)
        safety_q.put(event_direction)


class NavigationSystem(BaseNavigationSystem):
    """ класс навигационного блока """
    def _send_position_to_consumers(self):     
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME
        event = Event(source=BaseNavigationSystem.event_source_name,
                      destination=control_q_name,
                      operation="position_update",
                      parameters=self._position
                      )
        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        control_q.put(event)  

        safety_q_name = SAFETY_BLOCK_QUEUE_NAME
        event = Event(
            source=BaseNavigationSystem.event_source_name,
            destination=safety_q_name,
            operation="position_update",
            parameters=self._position
        )
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        safety_q.put(event)

# %%
# 3. создайте экземпляры изменённых классов и отправьте машинку по ранее предложенному маршруту
communication_gateway = CommunicationGateway(queues_dir=queues_dir, log_level=LOG_ERROR)
control_system = ControlSystem(queues_dir=queues_dir, log_level=LOG_INFO)
navigation_system = NavigationSystem(queues_dir=queues_dir, log_level=LOG_ERROR)
# Out:
# [ИНФО][QUEUES] регистрируем очередь communication
# [ИНФО][QUEUES] регистрируем очередь control
# [ИНФО][CONTROL] создана система управления
# [ИНФО][QUEUES] регистрируем очередь navigation

# %%
# создадим все остальные компоненты

if afcs_present:
    mission_sender = MissionSender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)
    telemetry_sender = TelemetrySender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)

mission_planner = MissionPlanner(
    queues_dir, afcs_present=afcs_present, mission=mission)

sitl = SITL(
    queues_dir=queues_dir, position=home,
    car_id=car_id, post_telemetry=afcs_present, log_level=LOG_ERROR)

servos = Servos(queues_dir=queues_dir, log_level=LOG_ERROR)
cargo_bay = CargoBay(queues_dir=queues_dir, log_level=LOG_INFO)

safety_block = SafetyBlock(queues_dir=queues_dir, log_level=LOG_INFO)
# Out:
# [ИНФО][QUEUES] регистрируем очередь planner.mqtt
# [ИНФО][QUEUES] регистрируем очередь sitl.mqtt
# [ИНФО][QUEUES] регистрируем очередь planner
# [ИНФО][MISSION PLANNER] создана система планирования заданий
# [ИНФО][QUEUES] регистрируем очередь sitl
# [ИНФО][QUEUES] регистрируем очередь servos
# [ИНФО][QUEUES] регистрируем очередь cargo
# [ИНФО][CARGO] создан компонент грузового отсека, отсек заблокирован
# [ИНФО][QUEUES] регистрируем очередь safety
# [ИНФО][SAFETY] создан ограничитель

# %%
# соберём все компоненты для запуска

# в зависимости от наличия СУПА используем разный набор компонентов - с передачей телеметрии или без

system_components = SystemComponentsContainer(
components=[
        # вариант компонентов с передачей телеметрии в СУПА
        mission_sender,
        telemetry_sender,
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system,
        safety_block
    ] if afcs_present else [
        # вариант компонентов для конфигурации без СУПА
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system,
        safety_block
    ])


#################################
# АКТИВАЦИЯ КИБЕРПРЕПЯТСТВИЙ
control_system.enable_surprises()
#################################

system_components.start()

# настройте этот параметр так, чтобы проверить работу ограничителя
sleep(1)

# останавливаем все компоненты
system_components.stop()

# удалим все созданные компоненты
system_components.clean()
# Out:
# [ИНФО][MISSION PLANNER] старт системы планирования заданий
# [ИНФО][CARGO] старт блока грузового отсека
# [ИНФО][CONTROL] старт системы управления
# [ИНФО][SAFETY] старт ограничителя
# [ИНФО][MISSION PLANNER] запрошена новая задача, отправляем получателям
# [ИНФО][MISSION PLANNER] новая задача отправлена в коммуникационный шлюз
# [ИНФО][CONTROL] установлена новая задача, начинаем следовать по маршруту, текущее время 12:07:21.213736
# [ИНФО][CONTROL] новая скорость 50 (была 0)
# [ИНФО][CONTROL] новое направление 122 (было 0)

# %% [markdown]
# #### Обеспечение ЦБ3: контроль доставки груза
#
# С помощью логики ограничителя выше мы реализовали обеспечение ЦБ1 (соблюдение заданных ограничений), однако есть ещё ЦБ3 (отгрузка только в заданной точке), не говоря о ЦБ2 (следование только по аутентичному маршруту).
#
# Для обеспечения ЦБ3 необходимо сделать следующее
# 1. изменить последовательность передачи команд, чтобы в блок управления грузовым отсеком (CargoBay) команды приходили только после проверки в Ограничителе
# 2. доработайте реализацию Ограничителя, чтобы команда на выгрузку передавалась в CargoBay только в конечной точке маршрута
# 3. продумайте логику работы блока безопасности, если система управления полностью перестанет работать (т.е. перестанет отправлять новые команды).
#
# Изменённая архитектура приведена на рис. 7.
#
# ![Ограничитель для обеспечения ЦБ1 и ЦБ3](images/ciac-arch-m312.png)
#
# Рис. 7. Ограничитель для обеспечения ЦБ1 и ЦБ3

# %%
# напишите свой код в этой ячейке, запустите машинку по маршруту, убедитесь, 
# что в конечной (и только в конечной!) точке CargoBay получает команду и успешно выполняет выгрузку
from multiprocessing import Queue

from src.config import CONTROL_SYSTEM_QUEUE_NAME
from src.config import SERVOS_QUEUE_NAME
from src.config import CONTROL_SYSTEM_QUEUE_NAME
from src.config import SAFETY_BLOCK_QUEUE_NAME
from src.config import CARGO_BAY_QUEUE_NAME
from src.navigation_system import BaseNavigationSystem
from src.communication_gateway import BaseCommunicationGateway
from src.control_system import BaseControlSystem
from src.event_types import Event

from src.safety_block import BaseSafetyBlock
from src.config import LOG_DEBUG
import math

class CommunicationGateway(BaseCommunicationGateway):
    """CommunicationGateway класс для реализации логики взаимодействия
    с системой планирования заданий

    Работает в отдельном процессе, поэтому создаётся как наследник класса Process
    """
    def _send_mission_to_consumers(self):
        """ метод для отправки сообщения с маршрутным заданием в систему управления """
        
        # имена очередей блоков находятся в файле src/config.py
        # события нужно отправлять в соответствие с диаграммой информационных потоков
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME

        # события передаются в виде экземпляров класса Event, 
        # описание класса находится в файле src/event_types.py
        event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=control_q_name,
                      operation="set_mission", 
                      parameters=self._mission
                      )

        # поиск в каталоге нужной очереди (в данном случае - системы управления)
        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        # отправка события в найденную очередь
        control_q.put(event)

        safety_q_name = SAFETY_BLOCK_QUEUE_NAME
        event = Event(
            source=BaseCommunicationGateway.event_source_name,
            destination=safety_q_name,
            operation="set_mission",
            parameters=self._mission
        )
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        safety_q.put(event)

class ControlSystem(BaseControlSystem):
    """ControlSystem блок расчёта управления """

    def _send_speed_and_direction_to_consumers(self, speed, direction):
        # servos_q_name = SERVOS_QUEUE_NAME
        # servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        # # отправка сообщения с желаемой скоростью
        # event_speed = Event(source=BaseControlSystem.event_source_name,
        #                     destination=servos_q_name,
        #                     operation="set_speed",
        #                     parameters=speed
        #                     )
        # # отправка сообщения с желаемым направлением
        # event_direction = Event(source=BaseControlSystem.event_source_name,
        #                         destination=servos_q_name,
        #                         operation="set_direction",
        #                         parameters=direction
        #                         )

        # servos_q.put(event_speed)
        # servos_q.put(event_direction)
        
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        
        event_speed = Event(
            source=BaseControlSystem.event_source_name,
            destination=safety_q_name,
            operation="set_speed",
            parameters=speed
        )
        event_direction = Event(
            source=BaseControlSystem.event_source_name,
            destination=safety_q_name,
            operation="set_direction",
            parameters=direction
        )
        safety_q.put(event_speed)
        safety_q.put(event_direction)

    def _release_cargo(self):
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME

        event_release_cargo = Event(
            source=BaseControlSystem.event_source_name,
            destination=safety_q_name,
            operation="release_cargo",
            parameters=None
        )

        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        safety_q.put(event_release_cargo)


    def _lock_cargo(self):
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME

        event_lock_cargo = Event(
            source=BaseControlSystem.event_source_name,
            destination=safety_q_name,
            operation="lock_cargo",
            parameters=None
        )

        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        safety_q.put(event_lock_cargo)


class NavigationSystem(BaseNavigationSystem):
    """ класс навигационного блока """
    def _send_position_to_consumers(self):     
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME
        event = Event(source=BaseNavigationSystem.event_source_name,
                      destination=control_q_name,
                      operation="position_update",
                      parameters=self._position
                      )
        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        control_q.put(event)  

        safety_q_name = SAFETY_BLOCK_QUEUE_NAME
        event = Event(
            source=BaseNavigationSystem.event_source_name,
            destination=safety_q_name,
            operation="position_update",
            parameters=self._position
        )
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        safety_q.put(event)

class SafetyBlock(BaseSafetyBlock):
    """ класс ограничений безопасности """

    def _set_new_direction(self, direction: float):
        """ установка нового направления перемещения """

        self._log_message(LOG_INFO, f"текущие координаты: {self._position}")
        self._log_message(LOG_DEBUG, f"маршрутное задание: {self._mission}")
        self._log_message(LOG_DEBUG, f"состояние маршруте: {self._route}")
        # TODO реализовать контроль безопасности изменения направления
        target_point = self._route.next_point()
        current_point = self._position
        target_direction = self._calculate_bearing(current_point, target_point)
        if not self._mission or not self._position or not self._route:
            self._log_message(LOG_ERROR, f"Неизвестный маршрут или позиция! Остановка.")
            self._direction = 0
            self._speed = 0
            self._send_direction_to_consumers()
            self._send_speed_to_consumers()
            return

        if abs(direction - target_direction) > 1:  # Допустимое отклонение 1 градус
            self._log_message(LOG_ERROR, f"Некорректное направление! Запрошено: {direction}, ожидалось: {target_direction}")
            self._direction = target_direction
            self._send_direction_to_consumers()
            return  
        
        self._direction = direction
        self._send_direction_to_consumers()

    def _set_new_speed(self, speed: float):
        """ установка новой скорости """
        # TODO реализовать контроль безопасности изменения скорости
        current_limit = self._route.calculate_speed()

        if not self._mission or not self._position or not self._route:
            self._log_message(LOG_ERROR, f"Неизвестный маршрут или позиция! Остановка.")
            self._direction = 0
            self._speed = 0
            self._send_direction_to_consumers()
            self._send_speed_to_consumers()
            return
        
        if speed > current_limit:
            self._log_message(LOG_ERROR, f"Превышение скорости! Лимит: {current_limit}, запрошено: {speed}")
            self._speed = current_limit
        else:
            self._speed = speed
        
        self._send_speed_to_consumers()
        self._send_direction_to_consumers()
    
    def _calculate_bearing(self, start: GeoPoint, end: GeoPoint) -> float:
        delta_longitude = end.longitude - start.longitude
        x = math.sin(math.radians(delta_longitude)) * \
            math.cos(math.radians(end.latitude))
        y = math.cos(math.radians(start.latitude)) * math.sin(math.radians(end.latitude)) - \
            math.sin(math.radians(start.latitude)) * math.cos(math.radians(end.latitude)) * \
            math.cos(math.radians(delta_longitude))

        initial_bearing_rad = math.atan2(x, y)

        initial_bearing_deg = math.degrees(initial_bearing_rad)

        compass_bearing = (initial_bearing_deg + 360) % 360

        return compass_bearing


    def _send_speed_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем скорость получателям")
        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_speed",
                            parameters=self._speed
                            )
        servos_q.put(event_speed)

    def _send_direction_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем направление получателям")

        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_direction",
                            parameters=self._direction
                            )
        servos_q.put(event_speed)

    def _lock_cargo(self, _):
        self._log_message(LOG_INFO, "Блокировка грузового отсека")
        self._send_lock_cargo_to_consumers()

    def _release_cargo(self, _):
        if not self._mission or not self._position or not self._route:
            self._log_message(LOG_ERROR, "Неизвестный маршрут!")
            self._speed = 0
            self._direction = 0
            self._send_speed_to_consumers()
            self._send_direction_to_consumers()
            return
        if not self._route.route_finished:
            self._log_message(LOG_INFO, "Выгружать еще рано! ")
            return
        self._send_release_cargo_to_consumers()
        
    def _send_lock_cargo_to_consumers(self):
        self._log_message(LOG_DEBUG, "Отправляем команду на блокировку грузового отсека")
        event = Event(
            source=self.event_source_name,
            destination=CARGO_BAY_QUEUE_NAME,
            operation="lock_cargo",
            parameters=None
        )
        cargo_bay = self._queues_dir.get_queue(CARGO_BAY_QUEUE_NAME)
        cargo_bay.put(event)

    def _send_release_cargo_to_consumers(self):
        self._log_message(LOG_DEBUG, "Отправляем команду на блокировку грузового отсека")
        event = Event(
            source=self.event_source_name,
            destination=CARGO_BAY_QUEUE_NAME,
            operation="release_cargo",
            parameters=None
        )
        cargo_bay = self._queues_dir.get_queue(CARGO_BAY_QUEUE_NAME)
        cargo_bay.put(event)

communication_gateway = CommunicationGateway(queues_dir=queues_dir, log_level=LOG_ERROR)
control_system = ControlSystem(queues_dir=queues_dir, log_level=LOG_INFO)
navigation_system = NavigationSystem(queues_dir=queues_dir, log_level=LOG_ERROR)
# Out:
# [ИНФО][QUEUES] регистрируем очередь communication
# [ИНФО][QUEUES] регистрируем очередь control
# [ИНФО][CONTROL] создана система управления
# [ИНФО][QUEUES] регистрируем очередь navigation

# %% [markdown]
# #### *Опциональное задание повышенной сложности* Обеспечение ЦБ2
#
# **Перед началом работы над этой задачей рекомендуем сохранить все текущие изменения в git репозитории (git commit, git push).**
#
# Напомним цель безопасности №2 (ЦБ2): "При любых обстоятельствах АНТС выполняет только аутентичный (подлинный) маршрут"
#
# Обеспечение ЦБ2 потребует
# - внедрения механизма **контроля аутентичности маршрутного задания** (mission), а значит
# - помимо изменения **блока безопасности** (SafetyBlock), модификации
#   - системы **планирования задания** (MissionPlanner)
#   - **коммуникационного шлюза** (CommunicationGateway)
#   - и, возможно, **системы управления** (ControlSystem).
#
# Для решения этой задачи допустимо менять код соответствующих модулей в папке src.
#
# Возможным решением является внедрение механизма цифровой подписи, верификацией которой будет заниматься блок безопасности. В этой ситуации если коммуникационный шлюз (блок "1. Связь" на рис. 5 в модуле 1) оказался скомпрометированным и изменил маршрутное задание, оно не должно пройти проверку подлинности в блоке безопасности.
#
# **Рекомендуем эту задачу делать в последнюю очередь**, *после успешного выполнения модуля 4*, поскольку успешное выполнение модуля 4 принесёт больше баллов, чем внедрение цифровой подписи и обеспечение ЦБ2.
# К сведению, реализованные в этой версии киберпрепятствия не предполагают компрометацию маршрутного задания.
#
# Конечно, если будут решены все основные задачи и к тому же обеспечен контроль аутентичности маршрутного задания, такая работа с высокой вероятностью окажется лучшей.

# %%
# если вы собираетесь выполнить это задание, напишите в этой ячейке код выполнения изменённых блоков. 
# cам код допускается редактировать в папке src
# в случае успешной реализации машинка должна успешно пройти по маршруту, а в случае искажения маршрутного задания в блоке коммуникационного шлюза должна остаться на месте, 
# при этом именно блок безопасности должен заблокировать движение

# %% [markdown]
# ### Задание 3.2. Монитор безопасности

# %% [markdown]
# В текущей реализации каждый блок сам решает куда и какие данные ему отправлять. Это приемлемо, когда каждый блок рассматривается как благонадёжный. Однако нельзя исключать ситуацию успешной компрометации какого-либо из блоков (одного или нескольких), в результате которой злоумышленник может получить полный контроль над частью системы.
#
# В такой ситуации необходимо выстроить внутреннюю "поверхность защиты", частью этой системы уже является блок "Ограничитель", однако необходимо сделать так, чтобы соответствующие запросы проходили только через него, а не в обход.
#
# Для решения этой задачи необходимо добавить новый блок "Монитор безопасности". Его задача - обеспечить контроль направления информационных потоков, допустить передачу данных только между теми блоками и в тех направлениях, которые задуманы архитектором системы. Тогда, например, попытка передать команду из системы управления напрямую в сервоприводы в обход ограничителя будет заблокирована.
#
# Возможно, возникнет вопрос, а что помешает злоумышленнику отправить команду в обход этого монитора безопасности. В рамках этой учебной инфраструктуры особо ничего, однако при разработке реальной системы можно использовать специализированные микроядерные операционные системы, такие как, например, KasperskyOS, которые обеспечат обязательное вовлечение монитора безопасности в контроль взаимодействия между блоками.
#
# Архитектура системы для решения задачи 3.2 должна выглядеть как на рис.8:
#
# ![Архитектура системы с монитором безопасности](images/ciac-arch-m32.png)
#
# Рис. 8. Архитектура бортовых систем с монитором безопасности

# %% [markdown]
# Базовый класс модуля безопасности находится в файле src/security_monitor.py, его менять не нужно.
#
# В следующей ячейке находится реализация класса SecurityMonitor

# %%
from src.security_monitory import BaseSecurityMonitor
from src.security_policy_type import SecurityPolicy

from src.config import COMMUNICATION_GATEWAY_QUEUE_NAME, LOG_DEBUG, LOG_ERROR, LOG_INFO
    
    
class SecurityMonitor(BaseSecurityMonitor):
    """ класс монитора безопасности """

    def __init__(self, queues_dir):
        super().__init__(queues_dir)
        self._init_set_security_policies()

    def _init_set_security_policies(self):
        """ инициализация политик безопасности """
        default_policies = [
            SecurityPolicy(
                source=COMMUNICATION_GATEWAY_QUEUE_NAME,
                destination=CONTROL_SYSTEM_QUEUE_NAME,
                operation='set_mission')
        ]
        self.set_security_policies(policies=default_policies)        

    def set_security_policies(self, policies):
        """ установка новых политик безопасности """
        self._security_policies = policies
        self._log_message(
            LOG_INFO, f"изменение политик безопасности: {policies}")

    def _check_event(self, event: Event):
        """ проверка входящих событий """
        self._log_message(
            LOG_DEBUG, f"проверка события {event}, по умолчанию выполнение запрещено")

        authorized = False
        request = SecurityPolicy(
            source=event.source,
            destination=event.destination,
            operation=event.operation)

        if request in self._security_policies:
            self._log_message(
                LOG_DEBUG, "событие разрешено политиками, выполняем")
            authorized = True

        if authorized is False:
            self._log_message(LOG_ERROR, f"событие не разрешено политиками безопасности! {event}")
        return authorized

# %% [markdown]
# Обратите внимание на этот код:
# ```python
#     def _init_set_security_policies(self):
#         """ инициализация политик безопасности """
#         default_policies = [
#             SecurityPolicy(
#                 source=COMMUNICATION_GATEWAY_QUEUE_NAME,
#                 destination=CONTROL_SYSTEM_QUEUE_NAME,
#                 operation='set_mission')
#         ]
#         self.set_security_policies(policies=default_policies)
# ```
#
# В нём инициализируется политика безопасности, разрешающая запрос set_mission от коммуникационного шлюза в систему управления.
#
# Код политики безопасности в строка 6-9:
# ```python
# SecurityPolicy(
#                 source=COMMUNICATION_GATEWAY_QUEUE_NAME,
#                 destination=CONTROL_SYSTEM_QUEUE_NAME,
#                 operation='set_mission')
# ```
#
# Шаблон политики безопасности описан в файле src/security_policy_type.py:
# ```python
# @dataclass
# class SecurityPolicy:
#     """ политика безопасности """
#     source: str         # отправитель запроса
#     destination: str    # получатель
#     operation: str      # запрашиваемая операция
#
# ```
#
# По аналогии в методе _init_set_security_policies допишите другие политики безопасности, чтобы разрешить взаимодействия согласно диаграмме на рис.7. выше.

# %% [markdown]
# Теперь необходимо изменить взаимодействие между блоками так, чтобы оно всегда проходило через монитор безопасности. Для этого потребуется изменить соответствующие реализации внутренних блоков.

# %% [markdown]
# Ниже пример для блока навигации. Обратите внимание на выделенные строки и комментарии.
#
# ```python
# from src.navigation_system import BaseNavigationSystem
# from src.config import CONTROL_SYSTEM_QUEUE_NAME, SECURITY_MONITOR_QUEUE_NAME
#
#
# class NavigationSystem(BaseNavigationSystem):
#     """ класс навигационного блока """
#     def _send_position_to_consumers(self):
#         # событие для системы управления,
#         # поэтому в destination указываем CONTROL_SYSTEM_QUEUE_NAME
#         event = Event(source=self.event_source_name,
# >>>                      destination=CONTROL_SYSTEM_QUEUE_NAME,
#                       operation="position_update", parameters=self._position
#                       )
#         # но событие отправляем сначала на проверку в монитор безопасности,
#         # поэтому используем очередь с именем SECURITY_MONITOR_QUEUE_NAME
# >>>        security_monitor_q: Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
#         security_monitor_q.put(event)
#         # а в систему управления наше событие монитор безопасности отправит сам, если найдёт разрешающую эту операцию политику безопасности
#
# navigation_system = NavigationSystem(queues_dir=queues_dir)
# ```

# %% [markdown]
# from src.navigation_system import BaseNavigationSystem
# from src.config import CONTROL_SYSTEM_QUEUE_NAME, SECURITY_MONITOR_QUEUE_NAME
#
#
# class NavigationSystem(BaseNavigationSystem):
#     """ класс навигационного блока """
#     def _send_position_to_consumers(self):
#         event = Event(source=self.event_source_name,
#                       destination=CONTROL_SYSTEM_QUEUE_NAME,
#                       operation="position_update", parameters=self._position
#                       )
#         security_monitor_q: Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
#         security_monitor_q.put(event)
#
# navigation_system = NavigationSystem(queues_dir=queues_dir)

# %% [markdown]
# В файле tests/module/test_security_monitor.py можно увидеть тест логики работы монитора безопасности. Запустить его можно следующей командой:

# %%
# !pytest -svk security_monitor
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.3, pytest-8.3.4, pluggy-1.5.0 -- /home/fegres/Cyber/cyberimmune-autonomy--chvt-preview/.venv/bin/python
# cachedir: .pytest_cache
# rootdir: /home/fegres/Cyber/cyberimmune-autonomy--chvt-preview
# configfile: pytest.ini
# testpaths: tests
# collected 1 item
#
# tests/module/test_security_monitor.py::test_security_policies [ИНФО][QUEUES] создан каталог очередей
# [ИНФО][QUEUES] регистрируем очередь security
# [ИНФО][SECURITY] создан монитор безопасности
# [ИНФО][SECURITY] изменение политик безопасности: [SecurityPolicy(source='communication', destination='control', operation='set_mission')]
# [ОТЛАДКА][SECURITY] проверка события Event(source='communication', destination='control', operation='set_mission', parameters=None, extra_parameters=None, signature=None), по умолчанию выполнение запрещено
# [ОТЛАДКА][SECURITY] событие разрешено политиками, выполняем
# [ОТЛАДКА][SECURITY] проверка события Event(source='control', destination='safety', operation='set_speed', parameters=None, extra_parameters=None, signature=None), по умолчанию выполнение запрещено
# [ИНФО][SECURITY] изменение политик безопасности: [SecurityPolicy(source='communication', destination='control', operation='set_mission'), SecurityPolicy(source='control', destination='safety', operation='set_speed')]
# [ОТЛАДКА][SECURITY] проверка события Event(source='control', destination='safety', operation='set_speed', parameters=None, extra_parameters=None, signature=None), по умолчанию выполнение запрещено
# [ОТЛАДКА][SECURITY] событие разрешено политиками, выполняем
# [ОТЛАДКА][SECURITY] проверка события Event(source='communication', destination='cargo', operation='release_cargo', parameters=None, extra_parameters=None, signature=None), по умолчанию выполнение запрещено
# PASSED
#
# ============================== 1 passed in 0.02s ===============================

# %% [markdown]
# В одном кодовом блоке ниже (или нескольких - как будет удобнее)  сделайте следующее
#
# 1. Измените реализацию монитора безопасности в части правил проверки передаваемых сообщений в мониторе безопасности
# 2. Измените параметры отправки сообщений между элементами бортовых систем (блоками 1-7), чтобы они всегда отправлялись в очередь монитора безопасности (отправитель и получатель при этом не меняются)
# 3. После всех изменений убедитесь в том, что машинка по-прежнему успешно выполняет маршрутное задание и доставляет груз
# 4. Дополнительные баллы принесут автоматические тесты правил безопасности в файле tests/module/test_security_monitor.py - можно проверить, что все новые политики работают как ожидаются, а недопустимые взаимодействия (т.е. таких стрелок нет на рис. 8) блокируются

# %%
from src.security_monitory import BaseSecurityMonitor
from src.security_policy_type import SecurityPolicy

from src.config import COMMUNICATION_GATEWAY_QUEUE_NAME, NAVIGATION_QUEUE_NAME, SAFETY_BLOCK_QUEUE_NAME, CONTROL_SYSTEM_QUEUE_NAME, SECURITY_MONITOR_QUEUE_NAME
from src.config import LOG_DEBUG, LOG_ERROR, LOG_INFO
    
    
class SecurityMonitor(BaseSecurityMonitor):
    """ класс монитора безопасности """

    def __init__(self, queues_dir):
        super().__init__(queues_dir)
        self._init_set_security_policies()

    def _init_set_security_policies(self):
        """ инициализация политик безопасности """
        default_policies = [
            SecurityPolicy(
                source=COMMUNICATION_GATEWAY_QUEUE_NAME,
                destination=CONTROL_SYSTEM_QUEUE_NAME,
                operation='set_mission'
            ),
            SecurityPolicy(
                source=COMMUNICATION_GATEWAY_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='set_mission'
            ),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='set_speed'
            ),
            SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=SERVOS_QUEUE_NAME,
                operation='set_speed'
            ),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='set_direction'
            ),
            SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=SERVOS_QUEUE_NAME,
                operation='set_direction'
            ),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='release_cargo'
            ),
            SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=CARGO_BAY_QUEUE_NAME,
                operation='release_cargo'
            ),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='lock_cargo'
            ),
            SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=CARGO_BAY_QUEUE_NAME,
                operation='lock_cargo'
            ),
            SecurityPolicy(
                source=NAVIGATION_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='position_update'
            ),
            SecurityPolicy(
                source=NAVIGATION_QUEUE_NAME,
                destination=CONTROL_SYSTEM_QUEUE_NAME,
                operation='position_update'
            ),
        ]
        self.set_security_policies(policies=default_policies)        

    def set_security_policies(self, policies):
        """ установка новых политик безопасности """
        self._security_policies = policies
        self._log_message(LOG_INFO, f"изменение политик безопасности: {policies}")

    def _check_event(self, event: Event):
        """ проверка входящих событий """
        self._log_message(LOG_DEBUG, f"проверка события {event}, по умолчанию выполнение запрещено")

        authorized = False
        request = SecurityPolicy(
            source=event.source,
            destination=event.destination,
            operation=event.operation)

        if request in self._security_policies:
            self._log_message(LOG_DEBUG, "событие разрешено политиками, выполняем")
            authorized = True

        if authorized is False:
            self._log_message(LOG_ERROR, f"событие не разрешено политиками безопасности! {event}")
        return authorized

# %%
# 2. Модифицируем блоки для отправки через SecurityMonitor

class CommunicationGateway(BaseCommunicationGateway):
    def _send_mission_to_consumers(self):
        event = Event(
            source=self.event_source_name,
            destination=CONTROL_SYSTEM_QUEUE_NAME,
            operation="set_mission",
            parameters=self._mission
        )
        security_q: Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_q.put(event)
        event = Event(
            source=self.event_source_name,
            destination=SAFETY_BLOCK_QUEUE_NAME,
            operation="set_mission",
            parameters=self._mission
        )
        security_q: Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_q.put(event)

class ControlSystem(BaseControlSystem):
    def _send_speed_and_direction_to_consumers(self, speed, direction):
        events = [
            Event(
                source=BaseControlSystem.event_source_name,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation="set_speed",
                parameters=speed
            ),
            Event(
                source=BaseControlSystem.event_source_name,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation="set_direction",
                parameters=direction
            )
        ]
        security_q = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        for event in events:
            security_q.put(event)

    def _release_cargo(self):
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME

        event_release_cargo = Event(
            source=BaseControlSystem.event_source_name,
            destination=safety_q_name,
            operation="release_cargo",
            parameters=None
        )

        safety_q: Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        safety_q.put(event_release_cargo)

    def _lock_cargo(self):
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME

        event_lock_cargo = Event(
            source=BaseControlSystem.event_source_name,
            destination=safety_q_name,
            operation="lock_cargo",
            parameters=None
        )

        safety_q: Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        safety_q.put(event_lock_cargo)       

class NavigationSystem(BaseNavigationSystem):
    def _send_position_to_consumers(self):
        event = Event(
            source=self.event_source_name,
            destination=SAFETY_BLOCK_QUEUE_NAME,
            operation="position_update",
            parameters=self._position
        )
        security_q = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_q.put(event)
        event = Event(
            source=self.event_source_name,
            destination=CONTROL_SYSTEM_QUEUE_NAME,
            operation="position_update",
            parameters=self._position
        )
        security_q = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_q.put(event)

class SafetyBlock(BaseSafetyBlock):
    """ класс ограничений безопасности """

    def _set_new_direction(self, direction: float):
        """ установка нового направления перемещения """

        self._log_message(LOG_INFO, f"текущие координаты: {self._position}")
        self._log_message(LOG_DEBUG, f"маршрутное задание: {self._mission}")
        self._log_message(LOG_DEBUG, f"состояние маршруте: {self._route}")
        # TODO реализовать контроль безопасности изменения направления
        target_point = self._route.next_point()
        current_point = self._position
        target_direction = self._calculate_bearing(current_point, target_point)
        if not self._mission or not self._position or not self._route:
            self._log_message(LOG_ERROR, f"Неизвестный маршрут или позиция! Остановка.")
            self._direction = 0
            self._speed = 0
            self._send_direction_to_consumers()
            self._send_speed_to_consumers()
            return

        if abs(direction - target_direction) > 1:  # Допустимое отклонение 1 градус
            self._log_message(LOG_ERROR, f"Некорректное направление! Запрошено: {direction}, ожидалось: {target_direction}")
            self._direction = target_direction
            self._send_direction_to_consumers()
            return  
        
        self._direction = direction
        self._send_direction_to_consumers()

    def _set_new_speed(self, speed: float):
        """ установка новой скорости """
        # TODO реализовать контроль безопасности изменения скорости
        current_limit = self._route.calculate_speed()

        if not self._mission or not self._position or not self._route:
            self._log_message(LOG_ERROR, f"Неизвестный маршрут или позиция! Остановка.")
            self._direction = 0
            self._speed = 0
            self._send_direction_to_consumers()
            self._send_speed_to_consumers()
            return
        
        if speed > current_limit:
            self._log_message(LOG_ERROR, f"Превышение скорости! Лимит: {current_limit}, запрошено: {speed}")
            self._speed = current_limit
        else:
            self._speed = speed
        
        self._send_speed_to_consumers()
        self._send_direction_to_consumers()
    
    def _calculate_bearing(self, start: GeoPoint, end: GeoPoint) -> float:
        delta_longitude = end.longitude - start.longitude
        x = math.sin(math.radians(delta_longitude)) * \
            math.cos(math.radians(end.latitude))
        y = math.cos(math.radians(start.latitude)) * math.sin(math.radians(end.latitude)) - \
            math.sin(math.radians(start.latitude)) * math.cos(math.radians(end.latitude)) * \
            math.cos(math.radians(delta_longitude))

        initial_bearing_rad = math.atan2(x, y)

        initial_bearing_deg = math.degrees(initial_bearing_rad)

        compass_bearing = (initial_bearing_deg + 360) % 360

        return compass_bearing


    def _send_speed_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем скорость получателям")
        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_speed",
                            parameters=self._speed
                            )
        security_q: Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_q.put(event_speed)

    def _send_direction_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем направление получателям")

        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        # отправка сообщения с желаемой скоростью
        event_direction = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_direction",
                            parameters=self._direction
                            )
        security_q: Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME) 
        security_q.put(event_direction)

    def _lock_cargo(self, _):
        self._log_message(LOG_INFO, "Блокировка грузового отсека")
        self._send_lock_cargo_to_consumers()

    def _release_cargo(self, _):
        if not self._mission or not self._position or not self._route:
            self._log_message(LOG_ERROR, "Неизвестный маршрут!")
            self._speed = 0
            self._direction = 0
            self._send_speed_to_consumers()
            self._send_direction_to_consumers()
            return
        if not self._route.route_finished:
            self._log_message(LOG_INFO, "Выгружать еще рано! ")
            return
        self._send_release_cargo_to_consumers()
        
    def _send_lock_cargo_to_consumers(self):
        self._log_message(LOG_DEBUG, "Отправляем команду на блокировку грузового отсека")
        event = Event(
            source=self.event_source_name,
            destination=CARGO_BAY_QUEUE_NAME,
            operation="lock_cargo",
            parameters=None
        )
        security_q : Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_q.put(event)

    def _send_release_cargo_to_consumers(self):
        self._log_message(LOG_DEBUG, "Отправляем команду на блокировку грузового отсека")
        event = Event(
            source=self.event_source_name,
            destination=CARGO_BAY_QUEUE_NAME,
            operation="release_cargo",
            parameters=None
        )
        security_q : Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_q.put(event)

# %%
# 3. создайте экземпляры изменённых классов и отправьте машинку по ранее предложенному маршруту
from time import sleep
from geopy import Point as GeoPoint


from src.queues_dir import QueuesDirectory
from src.servos import Servos
from src.sitl import SITL
from src.cargo_bay import CargoBay
from src.mission_planner import MissionPlanner
from src.config import LOG_ERROR, LOG_INFO
from src.mission_planner_mqtt import MissionSender
from src.mission_planner import Mission
from src.sitl_mqtt import TelemetrySender
from src.system_wrapper import SystemComponentsContainer
from src.wpl_parser import WPLParser


# возьмём маршрут из модуля 2
wpl_file = "module2.wpl"

parser = WPLParser(wpl_file)    
points = parser.parse()
print(points)

from src.mission_type import GeoSpecificSpeedLimit
speed_limits = [
    GeoSpecificSpeedLimit(0, 50),
    GeoSpecificSpeedLimit(1, 20),
    GeoSpecificSpeedLimit(2, 60),
    GeoSpecificSpeedLimit(3, 20),
    GeoSpecificSpeedLimit(4, 60),
    GeoSpecificSpeedLimit(5, 40),
    GeoSpecificSpeedLimit(6, 30),
    GeoSpecificSpeedLimit(7, 60),
    GeoSpecificSpeedLimit(8, 30),
    GeoSpecificSpeedLimit(9, 40),
    GeoSpecificSpeedLimit(10, 20),
    GeoSpecificSpeedLimit(11, 20),
    GeoSpecificSpeedLimit(12, 40),
    GeoSpecificSpeedLimit(13, 20),
    GeoSpecificSpeedLimit(14, 50),
]


home = points[0]
mission = Mission(home=home, waypoints=points,speed_limits=speed_limits, armed=True)

# каталог очередей для передачи сообщений между блоками
queues_dir = QueuesDirectory() 


if afcs_present:
    mission_sender = MissionSender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)
    telemetry_sender = TelemetrySender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)

mission_planner = MissionPlanner(
    queues_dir, afcs_present=afcs_present, mission=mission)

sitl = SITL(
    queues_dir=queues_dir, position=home,
    car_id=car_id, post_telemetry=afcs_present, log_level=LOG_ERROR)

communication_gateway = CommunicationGateway(
    queues_dir=queues_dir, log_level=LOG_ERROR)
control_system = ControlSystem(queues_dir=queues_dir, log_level=LOG_INFO)

navigation_system = NavigationSystem(
    queues_dir=queues_dir, log_level=LOG_ERROR)
# Out:
# [Point(59.927085760656304, 30.339722531511693, 0.0), Point(59.926292180395535, 30.342233217591005, 0.0), Point(59.926173699944215, 30.34242633664008, 0.0), Point(59.92209171270232, 30.332035318339557, 0.0), Point(59.92200822727937, 30.331826106036402, 0.0), Point(59.924914940966076, 30.32745676097576, 0.0), Point(59.925423884727905, 30.32667892036145, 0.0), Point(59.92558545253803, 30.326394606205874, 0.0), Point(59.93032701710794, 30.319320571688525, 0.0), Point(59.93055856305187, 30.318969202307596, 0.0), Point(59.929748021505674, 30.316205517732527, 0.0), Point(59.92969417243625, 30.31602849193753, 0.0), Point(59.929621476053455, 30.315948025667083, 0.0), Point(59.929018359158015, 30.31544913479032, 0.0), Point(59.92887027073796, 30.315379397355926, 0.0), Point(59.92945185053862, 30.314794675790694, 0.0)]
# [ИНФО][QUEUES] создан каталог очередей
# [ИНФО][QUEUES] регистрируем очередь planner.mqtt
# [ИНФО][QUEUES] регистрируем очередь sitl.mqtt
# [ИНФО][QUEUES] регистрируем очередь planner
# [ИНФО][MISSION PLANNER] создана система планирования заданий
# [ИНФО][QUEUES] регистрируем очередь sitl
# [ИНФО][QUEUES] регистрируем очередь communication
# [ИНФО][QUEUES] регистрируем очередь control
# [ИНФО][CONTROL] создана система управления
# [ИНФО][QUEUES] регистрируем очередь navigation

# %%
# создадим все остальные компоненты


servos = Servos(queues_dir=queues_dir, log_level=LOG_ERROR)
cargo_bay = CargoBay(queues_dir=queues_dir, log_level=LOG_INFO)

safety_block = SafetyBlock(queues_dir=queues_dir, log_level=LOG_INFO)

security_monitor = SecurityMonitor(queues_dir=queues_dir)
# Out:
# [ИНФО][QUEUES] регистрируем очередь servos
# [ИНФО][QUEUES] регистрируем очередь cargo
# [ИНФО][CARGO] создан компонент грузового отсека, отсек заблокирован
# [ИНФО][QUEUES] регистрируем очередь safety
# [ИНФО][SAFETY] создан ограничитель
# [ИНФО][QUEUES] регистрируем очередь security
# [ИНФО][SECURITY] создан монитор безопасности
# [ИНФО][SECURITY] изменение политик безопасности: [SecurityPolicy(source='communication', destination='control', operation='set_mission'), SecurityPolicy(source='communication', destination='safety', operation='set_mission'), SecurityPolicy(source='control', destination='safety', operation='set_speed'), SecurityPolicy(source='safety', destination='servos', operation='set_speed'), SecurityPolicy(source='control', destination='safety', operation='set_direction'), SecurityPolicy(source='safety', destination='servos', operation='set_direction'), SecurityPolicy(source='control', destination='safety', operation='release_cargo'), SecurityPolicy(source='safety', destination='cargo', operation='release_cargo'), SecurityPolicy(source='control', destination='safety', operation='lock_cargo'), SecurityPolicy(source='safety', destination='cargo', operation='lock_cargo'), SecurityPolicy(source='navigation', destination='safety', operation='position_update'), SecurityPolicy(source='navigation', destination='control', operation='position_update')]

# %%
# соберём все компоненты для запуска

# в зависимости от наличия СУПА используем разный набор компонентов - с передачей телеметрии или без

system_components = SystemComponentsContainer(
components=[
        # вариант компонентов с передачей телеметрии в СУПА
        mission_sender,
        telemetry_sender,
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system,
        safety_block,
        security_monitor  
    ] if afcs_present else [
        # вариант компонентов для конфигурации без СУПА
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system,
        safety_block,
        security_monitor  
    ])


#################################
# АКТИВАЦИЯ КИБЕРПРЕПЯТСТВИЙ
control_system.enable_surprises()
#################################

system_components.start()

# настройте этот параметр так, чтобы проверить работу ограничителя
sleep(180)

# останавливаем все компоненты
system_components.stop()

# удалим все созданные компоненты
system_components.clean()
# Out:
# [ИНФО][MISSION PLANNER] старт системы планирования заданий
# [ИНФО][CARGO] старт блока грузового отсека
# [ИНФО][CONTROL] старт системы управления
# [ИНФО][SAFETY] старт ограничителя
# [ИНФО][SECURITY] старт блока грузового отсека
# [ИНФО][MISSION PLANNER] запрошена новая задача, отправляем получателям
# [ИНФО][MISSION PLANNER] новая задача отправлена в коммуникационный шлюз
# [ИНФО][CONTROL] установлена новая задача, начинаем следовать по маршруту, текущее время 12:07:25.184184
# [ИНФО][SAFETY] Блокировка грузового отсека
# [ИНФО][CONTROL] новая скорость 50 (была 0)
# [ИНФО][CONTROL] новое направление 122 (было 0)
# [ИНФО][CARGO] заблокировать грузовой отсек
# [ИНФО][CARGO] грузовой отсек заблокирован
# [ИНФО][SAFETY] текущие координаты: 59 55m 37.5087s N, 30 20m 23.0011s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 37.5087s N, 30 20m 23.0011s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 37.5087s N, 30 20m 23.0011s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 37.5087s N, 30 20m 23.0011s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 37.389s N, 30 20m 23.3792s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 37.2693s N, 30 20m 23.7573s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 37.1496s N, 30 20m 24.1355s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 37.0299s N, 30 20m 24.5136s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 36.9102s N, 30 20m 24.8917s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 36.8144s N, 30 20m 25.1942s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 36.6947s N, 30 20m 25.5723s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 36.5751s N, 30 20m 25.9505s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 36.4554s N, 30 20m 26.3286s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 36.3357s N, 30 20m 26.7068s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 36.2161s N, 30 20m 27.085s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 36.0964s N, 30 20m 27.4632s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 35.9768s N, 30 20m 27.8414s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 35.8572s N, 30 20m 28.2196s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 35.7376s N, 30 20m 28.5979s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 35.618s N, 30 20m 28.9762s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 35.4984s N, 30 20m 29.3545s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 35.3789s N, 30 20m 29.7328s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 35.2594s N, 30 20m 30.1111s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 35.1399s N, 30 20m 30.4895s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 35.0204s N, 30 20m 30.8679s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 34.901s N, 30 20m 31.2464s E
# [ИНФО][CONTROL] новое направление 121 (было 122)
# [ИНФО][SAFETY] текущие координаты: 59 55m 34.7816s N, 30 20m 31.6249s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 20 (была 50)
# [ИНФО][CONTROL] новое направление 320 (было 121)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 55m 34.6623s N, 30 20m 32.0035s E
# [ОШИБКА][SAFETY] Некорректное направление! Запрошено: 320.01634629603336, ожидалось: 140.01634629603336
# [ИНФО][CONTROL] новое направление 330 (было 320)
# [ИНФО][SAFETY] текущие координаты: 59 55m 34.5431s N, 30 20m 32.3823s E
# [ОШИБКА][SAFETY] Некорректное направление! Запрошено: 330.9342473413824, ожидалось: 150.9342473413824
# [ИНФО][CONTROL] новое направление 3 (было 330)
# [ИНФО][SAFETY] текущие координаты: 59 55m 34.4243s N, 30 20m 32.7615s E
# [ОШИБКА][SAFETY] Некорректное направление! Запрошено: 3.8442693691808927, ожидалось: 183.8442693691809
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 160 (была 20)
# [ИНФО][CONTROL] новое направление 231 (было 3)
# [ИНФО][SAFETY] сегмент пройден
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 34.3555s N, 30 20m 32.8764s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 34.2771s N, 30 20m 32.9633s E
# [ИНФО][CONTROL] новое направление 232 (было 231)
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 34.1875s N, 30 20m 32.9513s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 34.0209s N, 30 20m 32.5299s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 33.855s N, 30 20m 32.1072s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 33.6898s N, 30 20m 31.6837s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 33.5246s N, 30 20m 31.2601s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 33.3593s N, 30 20m 30.8365s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 33.1941s N, 30 20m 30.4129s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 33.0289s N, 30 20m 29.9893s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 32.8637s N, 30 20m 29.5658s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 32.7315s N, 30 20m 29.2269s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 32.5663s N, 30 20m 28.8033s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 32.4011s N, 30 20m 28.3797s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 32.2359s N, 30 20m 27.9561s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 32.0707s N, 30 20m 27.5325s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 31.9055s N, 30 20m 27.1089s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 31.7403s N, 30 20m 26.6852s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 31.5751s N, 30 20m 26.2616s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 31.4099s N, 30 20m 25.838s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 31.2447s N, 30 20m 25.4144s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 31.0795s N, 30 20m 24.9908s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 30.9143s N, 30 20m 24.5672s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 30.7491s N, 30 20m 24.1435s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 30.5839s N, 30 20m 23.7199s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 30.4187s N, 30 20m 23.2963s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 30.2536s N, 30 20m 22.8726s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 30.0884s N, 30 20m 22.449s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 29.9232s N, 30 20m 22.0254s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 29.758s N, 30 20m 21.6017s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 29.5929s N, 30 20m 21.1781s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 29.4277s N, 30 20m 20.7544s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 29.2625s N, 30 20m 20.3308s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 29.0973s N, 30 20m 19.9071s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 28.9322s N, 30 20m 19.4834s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 28.767s N, 30 20m 19.0598s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 28.6019s N, 30 20m 18.6361s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 28.4367s N, 30 20m 18.2125s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 28.2715s N, 30 20m 17.7888s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 28.1064s N, 30 20m 17.3651s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 27.9412s N, 30 20m 16.9414s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 27.8091s N, 30 20m 16.6025s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 27.644s N, 30 20m 16.1788s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 27.4788s N, 30 20m 15.7551s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 27.3137s N, 30 20m 15.3314s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 27.1486s N, 30 20m 14.9077s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 26.9834s N, 30 20m 14.484s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 26.8183s N, 30 20m 14.0603s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 26.6532s N, 30 20m 13.6366s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 26.4881s N, 30 20m 13.2129s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 26.3229s N, 30 20m 12.7892s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 26.1578s N, 30 20m 12.3654s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 25.9927s N, 30 20m 11.9417s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 25.8276s N, 30 20m 11.518s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 25.6625s N, 30 20m 11.0942s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 25.4974s N, 30 20m 10.6705s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 25.3323s N, 30 20m 10.2467s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 25.1672s N, 30 20m 9.82294s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 25.0022s N, 30 20m 9.39917s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 24.8371s N, 30 20m 8.97539s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 24.672s N, 30 20m 8.55161s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 24.5069s N, 30 20m 8.12781s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 24.3419s N, 30 20m 7.70401s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 24.1768s N, 30 20m 7.28021s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 24.0118s N, 30 20m 6.85639s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 23.8467s N, 30 20m 6.43257s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 23.6817s N, 30 20m 6.00872s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 23.5167s N, 30 20m 5.58487s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 23.3516s N, 30 20m 5.16101s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 23.1866s N, 30 20m 4.73713s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 23.0216s N, 30 20m 4.31325s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 22.8566s N, 30 20m 3.88935s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 22.6916s N, 30 20m 3.46545s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 22.5267s N, 30 20m 3.04152s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 22.3617s N, 30 20m 2.61759s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 22.1967s N, 30 20m 2.19364s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 22.0648s N, 30 20m 1.85447s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 21.8998s N, 30 20m 1.4305s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 21.7349s N, 30 20m 1.0065s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 21.57s N, 30 20m 0.582493s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 21.4051s N, 30 20m 0.158465s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 21.2402s N, 30 19m 59.7344s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 21.0753s N, 30 19m 59.3103s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 20.9104s N, 30 19m 58.8862s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 20.7456s N, 30 19m 58.4621s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 20.5808s N, 30 19m 58.0379s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 20.416s N, 30 19m 57.6137s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 20.2512s N, 30 19m 57.1895s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 20.0865s N, 30 19m 56.7652s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 19.9218s N, 30 19m 56.3408s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 55m 19.7572s N, 30 19m 55.9163s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 20 (была 160)
# [ИНФО][CONTROL] новое направление 231 (было 232)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] Выгружать еще рано!
# [ИНФО][SAFETY] текущие координаты: 59 55m 19.5927s N, 30 19m 55.4917s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 19.4283s N, 30 19m 55.0669s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 60 (была 20)
# [ИНФО][CONTROL] новое направление 322 (было 231)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 55m 19.2641s N, 30 19m 54.6417s E
# [ИНФО][CONTROL] новое направление 323 (было 322)
# [ИНФО][SAFETY] текущие координаты: 59 55m 19.2085s N, 30 19m 54.5014s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 19.1523s N, 30 19m 54.362s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 19.3668s N, 30 19m 54.0378s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 19.5824s N, 30 19m 53.7164s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 19.799s N, 30 19m 53.398s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 20.0158s N, 30 19m 53.0797s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 20.2325s N, 30 19m 52.7615s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 20.4493s N, 30 19m 52.4432s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 20.666s N, 30 19m 52.125s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 20.8828s N, 30 19m 51.8067s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 21.0995s N, 30 19m 51.4884s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 21.3163s N, 30 19m 51.1701s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 21.533s N, 30 19m 50.8519s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 21.7498s N, 30 19m 50.5336s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 21.9665s N, 30 19m 50.2152s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 22.1399s N, 30 19m 49.9606s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 22.3566s N, 30 19m 49.6423s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 22.5733s N, 30 19m 49.3239s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 22.79s N, 30 19m 49.0056s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 23.0068s N, 30 19m 48.6872s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 23.2235s N, 30 19m 48.3688s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 23.4402s N, 30 19m 48.0504s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 23.6569s N, 30 19m 47.732s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 23.8736s N, 30 19m 47.4136s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 24.0903s N, 30 19m 47.0952s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 24.3069s N, 30 19m 46.7767s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 24.5236s N, 30 19m 46.4583s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 24.7403s N, 30 19m 46.1398s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 24.957s N, 30 19m 45.8213s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 25.1736s N, 30 19m 45.5028s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 25.3903s N, 30 19m 45.1843s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 25.6069s N, 30 19m 44.8657s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 25.8236s N, 30 19m 44.5472s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 26.0402s N, 30 19m 44.2286s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 26.2569s N, 30 19m 43.91s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 26.4735s N, 30 19m 43.5914s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 26.6901s N, 30 19m 43.2728s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 26.9067s N, 30 19m 42.9541s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 27.1233s N, 30 19m 42.6354s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 27.3399s N, 30 19m 42.3167s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 27.5565s N, 30 19m 41.9979s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 27.773s N, 30 19m 41.6792s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 27.9896s N, 30 19m 41.3603s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 28.2061s N, 30 19m 41.0415s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 28.4226s N, 30 19m 40.7225s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 28.6391s N, 30 19m 40.4036s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 28.8556s N, 30 19m 40.0845s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 29.0287s N, 30 19m 39.8292s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 29.2451s N, 30 19m 39.51s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 40 (была 60)
# [ИНФО][CONTROL] новое направление 322 (было 323)
# [ИНФО][SAFETY] текущие координаты: 59 55m 29.4615s N, 30 19m 39.1907s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 55m 29.6778s N, 30 19m 38.8713s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 29.8941s N, 30 19m 38.5516s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 30.1102s N, 30 19m 38.2316s E
# [ИНФО][CONTROL] новое направление 321 (было 322)
# [ИНФО][SAFETY] текущие координаты: 59 55m 30.326s N, 30 19m 37.9107s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 30.4831s N, 30 19m 37.6724s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 30.6253s N, 30 19m 37.4543s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 30.7672s N, 30 19m 37.2353s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 30.9088s N, 30 19m 37.0155s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 31.0502s N, 30 19m 36.7951s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 31.1914s N, 30 19m 36.5743s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 30 (была 40)
# [ИНФО][CONTROL] новое направление 318 (было 321)
# [ИНФО][SAFETY] текущие координаты: 59 55m 31.3325s N, 30 19m 36.3532s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][CONTROL] новое направление 317 (было 318)
# [ИНФО][SAFETY] текущие координаты: 59 55m 31.4735s N, 30 19m 36.1318s E
# [ИНФО][CONTROL] новое направление 316 (было 317)
# [ИНФО][SAFETY] текущие координаты: 59 55m 31.6143s N, 30 19m 35.9099s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 31.7548s N, 30 19m 35.6875s E
# [ИНФО][CONTROL] новое направление 313 (было 316)
# [ИНФО][SAFETY] текущие координаты: 59 55m 31.895s N, 30 19m 35.4639s E
# [ИНФО][CONTROL] новое направление 309 (было 313)
# [ИНФО][SAFETY] текущие координаты: 59 55m 31.9961s N, 30 19m 35.287s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 60 (была 30)
# [ИНФО][CONTROL] новое направление 323 (было 309)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 55m 32.0939s N, 30 19m 35.1025s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 32.187s N, 30 19m 34.9088s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 32.2733s N, 30 19m 34.7029s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 32.4888s N, 30 19m 34.3812s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 32.7044s N, 30 19m 34.06s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 32.9203s N, 30 19m 33.7394s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 33.1362s N, 30 19m 33.4188s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 33.3521s N, 30 19m 33.0982s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 33.568s N, 30 19m 32.7776s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 33.7839s N, 30 19m 32.457s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 33.9998s N, 30 19m 32.1364s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 34.2157s N, 30 19m 31.8158s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 34.4316s N, 30 19m 31.4952s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 34.6043s N, 30 19m 31.2387s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 34.8202s N, 30 19m 30.9181s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 35.0361s N, 30 19m 30.5975s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 35.2519s N, 30 19m 30.2768s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 35.4678s N, 30 19m 29.9562s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 35.6837s N, 30 19m 29.6355s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 35.8996s N, 30 19m 29.3149s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 36.1154s N, 30 19m 28.9942s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 36.3313s N, 30 19m 28.6735s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 36.5472s N, 30 19m 28.3529s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 36.763s N, 30 19m 28.0322s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 36.9789s N, 30 19m 27.7115s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 37.1947s N, 30 19m 27.3908s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 37.4106s N, 30 19m 27.0701s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 37.6264s N, 30 19m 26.7494s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 37.8423s N, 30 19m 26.4286s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 38.0581s N, 30 19m 26.1079s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 38.274s N, 30 19m 25.7872s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 38.4898s N, 30 19m 25.4664s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 38.7057s N, 30 19m 25.1457s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 38.9215s N, 30 19m 24.8249s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 39.1373s N, 30 19m 24.5041s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 39.3532s N, 30 19m 24.1833s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 39.569s N, 30 19m 23.8625s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 39.7848s N, 30 19m 23.5417s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 40.0006s N, 30 19m 23.2209s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 40.2165s N, 30 19m 22.9001s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 40.4323s N, 30 19m 22.5793s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 40.6481s N, 30 19m 22.2585s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 40.8639s N, 30 19m 21.9376s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 41.0365s N, 30 19m 21.6809s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 41.2523s N, 30 19m 21.3601s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 41.4681s N, 30 19m 21.0392s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 41.6839s N, 30 19m 20.7183s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 41.8997s N, 30 19m 20.3974s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 42.1155s N, 30 19m 20.0765s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 42.3313s N, 30 19m 19.7556s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 42.5471s N, 30 19m 19.4346s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 42.7628s N, 30 19m 19.1137s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 42.9786s N, 30 19m 18.7927s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 43.1944s N, 30 19m 18.4718s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 43.4101s N, 30 19m 18.1508s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 43.6259s N, 30 19m 17.8298s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 43.8416s N, 30 19m 17.5088s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 44.0574s N, 30 19m 17.1878s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 44.2731s N, 30 19m 16.8668s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 44.4889s N, 30 19m 16.5457s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 44.7046s N, 30 19m 16.2247s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 44.9203s N, 30 19m 15.9036s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 45.136s N, 30 19m 15.5825s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 45.3517s N, 30 19m 15.2614s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 45.5674s N, 30 19m 14.9402s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 45.7831s N, 30 19m 14.619s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 45.9988s N, 30 19m 14.2979s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 46.2145s N, 30 19m 13.9766s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 46.4302s N, 30 19m 13.6554s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 46.6458s N, 30 19m 13.3341s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 46.8615s N, 30 19m 13.0129s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 47.0771s N, 30 19m 12.6915s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 47.2927s N, 30 19m 12.3702s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 47.5083s N, 30 19m 12.0488s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 47.7239s N, 30 19m 11.7273s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 47.8964s N, 30 19m 11.4701s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 48.1119s N, 30 19m 11.1486s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 48.3274s N, 30 19m 10.827s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 48.5429s N, 30 19m 10.5053s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 48.7584s N, 30 19m 10.1835s E
# [ИНФО][CONTROL] новое направление 322 (было 323)
# [ИНФО][SAFETY] текущие координаты: 59 55m 48.9739s N, 30 19m 9.86169s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 30 (была 60)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 55m 49.1892s N, 30 19m 9.53968s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 49.4045s N, 30 19m 9.21744s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 49.6197s N, 30 19m 8.89479s E
# [ИНФО][CONTROL] новое направление 321 (было 322)
# [ИНФО][SAFETY] текущие координаты: 59 55m 49.8344s N, 30 19m 8.57101s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 40 (была 30)
# [ИНФО][CONTROL] новое направление 240 (было 321)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 55m 49.9414s N, 30 19m 8.40834s E
# [ИНФО][CONTROL] новое направление 239 (было 240)
# [ИНФО][SAFETY] текущие координаты: 59 55m 50.0483s N, 30 19m 8.24506s E
# [ИНФО][CONTROL] новое направление 237 (было 239)
# [ИНФО][SAFETY] текущие координаты: 59 55m 50.1546s N, 30 19m 8.08063s E
# [ИНФО][CONTROL] новое направление 236 (было 237)
# [ИНФО][SAFETY] текущие координаты: 59 55m 50.2597s N, 30 19m 7.91299s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 50.1715s N, 30 19m 7.60154s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 50.0796s N, 30 19m 7.29422s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 49.9842s N, 30 19m 6.99122s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 49.8853s N, 30 19m 6.69273s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 49.7861s N, 30 19m 6.39468s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 49.6866s N, 30 19m 6.09694s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 49.587s N, 30 19m 5.79941s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 49.4874s N, 30 19m 5.5019s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 49.3877s N, 30 19m 5.20438s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 49.2881s N, 30 19m 4.90687s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 49.1884s N, 30 19m 4.60934s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 49.0888s N, 30 19m 4.31181s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 48.9892s N, 30 19m 4.01427s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 48.8896s N, 30 19m 3.71673s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 48.79s N, 30 19m 3.41918s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 48.7103s N, 30 19m 3.18113s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 48.6107s N, 30 19m 2.88356s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 48.5111s N, 30 19m 2.58598s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 48.4115s N, 30 19m 2.2884s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 48.3119s N, 30 19m 1.9908s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 48.2123s N, 30 19m 1.69319s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 48.1128s N, 30 19m 1.39557s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 48.0132s N, 30 19m 1.09793s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 47.9137s N, 30 19m 0.800282s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 47.8142s N, 30 19m 0.502613s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 47.7147s N, 30 19m 0.204925s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 47.6152s N, 30 18m 59.9072s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 47.5157s N, 30 18m 59.6095s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 47.4163s N, 30 18m 59.3117s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 47.3169s N, 30 18m 59.0139s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 47.2175s N, 30 18m 58.716s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 20 (была 40)
# [ИНФО][CONTROL] новое направление 238 (было 236)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 55m 47.1182s N, 30 18m 58.4181s E
# [ИНФО][CONTROL] новое направление 240 (было 238)
# [ИНФО][SAFETY] текущие координаты: 59 55m 47.019s N, 30 18m 58.12s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 215 (было 240)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 55m 46.92s N, 30 18m 57.8216s E
# [ИНФО][CONTROL] новое направление 208 (было 215)
# [ИНФО][SAFETY] текущие координаты: 59 55m 46.8731s N, 30 18m 57.6691s E
# [ИНФО][CONTROL] новое направление 194 (было 208)
# [ИНФО][SAFETY] текущие координаты: 59 55m 46.8285s N, 30 18m 57.5139s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 40 (была 20)
# [ИНФО][CONTROL] новое направление 201 (было 194)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 55m 46.7558s N, 30 18m 57.409s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 46.677s N, 30 18m 57.3235s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 46.5902s N, 30 18m 57.2777s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 46.5034s N, 30 18m 57.2319s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 46.336s N, 30 18m 57.1029s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 46.1689s N, 30 18m 56.9724s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 46.002s N, 30 18m 56.8404s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 45.8352s N, 30 18m 56.7084s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 45.6684s N, 30 18m 56.5761s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 45.5017s N, 30 18m 56.4435s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 45.335s N, 30 18m 56.3108s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 45.1683s N, 30 18m 56.178s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 45.0016s N, 30 18m 56.0452s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 44.8349s N, 30 18m 55.9123s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 44.6683s N, 30 18m 55.7794s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 20 (была 40)
# [ИНФО][CONTROL] новое направление 194 (было 201)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 55m 44.535s N, 30 18m 55.6729s E
# [ИНФО][CONTROL] новое направление 191 (было 194)
# [ИНФО][SAFETY] текущие координаты: 59 55m 44.3684s N, 30 18m 55.5398s E
# [ИНФО][CONTROL] новое направление 184 (было 191)
# [ИНФО][SAFETY] текущие координаты: 59 55m 44.2018s N, 30 18m 55.4062s E
# [ИНФО][CONTROL] новое направление 176 (было 184)
# [ИНФО][SAFETY] текущие координаты: 59 55m 44.099s N, 30 18m 55.3441s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 50 (была 20)
# [ИНФО][CONTROL] новое направление 333 (было 176)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 55m 44.0112s N, 30 18m 55.3071s E
# [ИНФО][CONTROL] новое направление 334 (было 333)
# [ИНФО][SAFETY] текущие координаты: 59 55m 43.922s N, 30 18m 55.2894s E
# [ИНФО][CONTROL] новое направление 335 (было 334)
# [ИНФО][SAFETY] текущие координаты: 59 55m 43.8324s N, 30 18m 55.2961s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 43.9745s N, 30 18m 55.1362s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 44.1762s N, 30 18m 54.9402s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 44.3794s N, 30 18m 54.7505s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 44.5834s N, 30 18m 54.5644s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 44.7876s N, 30 18m 54.3794s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 44.992s N, 30 18m 54.1948s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 45.1965s N, 30 18m 54.0105s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 45.4009s N, 30 18m 53.8262s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 45.6054s N, 30 18m 53.642s E
# [ИНФО][SAFETY] текущие координаты: 59 55m 45.8098s N, 30 18m 53.4577s E
# [ИНФО][CONTROL] маршрут пройден, текущее время 12:10:19.317979
# [ИНФО][CONTROL] новая скорость 0.0 (была 50)
# [ИНФО][CONTROL] новое направление 0 (было 335)
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] текущие координаты: 59 55m 46.0142s N, 30 18m 53.2733s E
# [ОШИБКА][SAFETY] ошибка обработки команд: 'NoneType' object has no attribute 'longitude'
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][CARGO] выгрузка
# [ИНФО][CARGO] груз оставлен
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден

# %% [markdown]
# На этом модуль 3 завершён!
#
# Если у вас всё получилось, то вы создали защищённую автономную машинку - ещё уже не так-то просто использовать для нанесения критического ущерба людям и имуществу, потому что самые критические режимы проверяются вашим Ограничителем, а если вы ещё и внедрили Монитор Безопасности, то теперь злоумышленнику гораздо сложнее атаковать внутренние блоки, даже если он смог проникнуть в какую-то бортовую систему или внедрить вредоносный код.
#
# Осталось проверить эффективность получившейся защиты на полной трассе - в этом и заключается модуль 4 задания, для перехода к которому нужно открыть блокнот с именем cyberimmunity--autonomous-car-m4. Успеха!
