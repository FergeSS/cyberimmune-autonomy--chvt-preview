# %% [markdown]
# # Кибериммунная автономность$\\$Создание конструктивно защищённого автономного наземного транспортного средства$\\$Модуль 4
#
# ## О документе
#
# Версия 1.03
#
# Модуль 4 для регионального этапа соревнований по кибериммунной автономности

# %% [markdown]
# ### Модуль 4. Следование по трассе с киберпрепятствиями
#
# Для успешного выполнения этого задания необходимое активировать специальный режим работы виртуальной машинки - в рамках этого задания можно менять только блоки, отвечающие за безопасность (ограничитель, монитор безопасности), **другие блоки менять запрещено**.
#
# При прохождении маршрута будут имитироваться атаки со стороны злоумышленников, которые будут пытаться нарушить цели безопасности. Важно, чтобы им это не удалось.

# %% [markdown]
# 1. Запустите свою машинку и убедитесь, что она проходит всю трассу без нарушений ограничений скорости. При необходимости измените логику работы блока безопасности
# 2. Добавьте контроль доставки груза в модуле SafetyBlock - убедитесь, что груз доставляется до конечной точки маршрута.
# 3. Если в модуле 3 вы реализовали монитор безопасности - не забудьте его перенести в этот модуль, это принесёт дополнительные баллы!

# %% [markdown]
# Активация киберпрепятствий в системе управления:
#
# после инициализации системы управления добавьте следующую строку
# ```python
# control_system.enable_surprises()
# ```

# %% [markdown]
# В этом блоке добавьте все ваши реализации изменённых бортовых систем

# %%
# ваш код
from geopy import Point as GeoPoint
from src.security_monitory import BaseSecurityMonitor
from src.security_policy_type import SecurityPolicy
from multiprocessing import Queue
from src.event_types import Event
from src.navigation_system import BaseNavigationSystem
from src.communication_gateway import BaseCommunicationGateway
from src.control_system import BaseControlSystem
from src.safety_block import BaseSafetyBlock
from src.config import COMMUNICATION_GATEWAY_QUEUE_NAME, NAVIGATION_QUEUE_NAME, SAFETY_BLOCK_QUEUE_NAME, CONTROL_SYSTEM_QUEUE_NAME, SECURITY_MONITOR_QUEUE_NAME, SERVOS_QUEUE_NAME, CARGO_BAY_QUEUE_NAME
from src.config import LOG_DEBUG, LOG_ERROR, LOG_INFO
import math

    
class SecurityMonitor(BaseSecurityMonitor):
    """ класс монитора безопасности """

    def __init__(self, queues_dir):
        super().__init__(queues_dir)
        self._init_set_security_policies()

    def _init_set_security_policies(self):
        """ инициализация политик безопасности """
        default_policies = [
            SecurityPolicy(
                source=COMMUNICATION_GATEWAY_QUEUE_NAME,
                destination=CONTROL_SYSTEM_QUEUE_NAME,
                operation='set_mission'
            ),
            SecurityPolicy(
                source=COMMUNICATION_GATEWAY_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='set_mission'
            ),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='set_speed'
            ),
            SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=SERVOS_QUEUE_NAME,
                operation='set_speed'
            ),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='set_direction'
            ),
            SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=SERVOS_QUEUE_NAME,
                operation='set_direction'
            ),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='release_cargo'
            ),
            SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=CARGO_BAY_QUEUE_NAME,
                operation='release_cargo'
            ),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='lock_cargo'
            ),
            SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=CARGO_BAY_QUEUE_NAME,
                operation='lock_cargo'
            ),
            SecurityPolicy(
                source=NAVIGATION_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation='position_update'
            ),
            SecurityPolicy(
                source=NAVIGATION_QUEUE_NAME,
                destination=CONTROL_SYSTEM_QUEUE_NAME,
                operation='position_update'
            ),
        ]
        self.set_security_policies(policies=default_policies)        

    def set_security_policies(self, policies):
        """ установка новых политик безопасности """
        self._security_policies = policies
        self._log_message(LOG_INFO, f"изменение политик безопасности: {policies}")

    def _check_event(self, event: Event):
        """ проверка входящих событий """
        self._log_message(LOG_DEBUG, f"проверка события {event}, по умолчанию выполнение запрещено")

        authorized = False
        request = SecurityPolicy(
            source=event.source,
            destination=event.destination,
            operation=event.operation)

        if request in self._security_policies:
            self._log_message(LOG_DEBUG, "событие разрешено политиками, выполняем")
            authorized = True

        if authorized is False:
            self._log_message(LOG_ERROR, f"событие не разрешено политиками безопасности! {event}")
        return authorized

# 2. Модифицируем блоки для отправки через SecurityMonitor

class CommunicationGateway(BaseCommunicationGateway):
    def _send_mission_to_consumers(self):
        event = Event(
            source=self.event_source_name,
            destination=CONTROL_SYSTEM_QUEUE_NAME,
            operation="set_mission",
            parameters=self._mission
        )
        security_q: Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_q.put(event)
        event = Event(
            source=self.event_source_name,
            destination=SAFETY_BLOCK_QUEUE_NAME,
            operation="set_mission",
            parameters=self._mission
        )
        security_q: Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_q.put(event)

class ControlSystem(BaseControlSystem):
    def _send_speed_and_direction_to_consumers(self, speed, direction):
        events = [
            Event(
                source=BaseControlSystem.event_source_name,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation="set_speed",
                parameters=speed
            ),
            Event(
                source=BaseControlSystem.event_source_name,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation="set_direction",
                parameters=direction
            )
        ]
        security_q = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        for event in events:
            security_q.put(event)

    def _release_cargo(self):
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME

        event_release_cargo = Event(
            source=BaseControlSystem.event_source_name,
            destination=safety_q_name,
            operation="release_cargo",
            parameters=None
        )

        safety_q: Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        safety_q.put(event_release_cargo)

    def _lock_cargo(self):
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME

        event_lock_cargo = Event(
            source=BaseControlSystem.event_source_name,
            destination=safety_q_name,
            operation="lock_cargo",
            parameters=None
        )

        safety_q: Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        safety_q.put(event_lock_cargo)       

class NavigationSystem(BaseNavigationSystem):
    def _send_position_to_consumers(self):
        event = Event(
            source=self.event_source_name,
            destination=SAFETY_BLOCK_QUEUE_NAME,
            operation="position_update",
            parameters=self._position
        )
        security_q = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_q.put(event)
        event = Event(
            source=self.event_source_name,
            destination=CONTROL_SYSTEM_QUEUE_NAME,
            operation="position_update",
            parameters=self._position
        )
        security_q = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_q.put(event)

class SafetyBlock(BaseSafetyBlock):
    """ класс ограничений безопасности """

    def _set_new_direction(self, direction: float):
        """ установка нового направления перемещения """

        self._log_message(LOG_INFO, f"текущие координаты: {self._position}")
        self._log_message(LOG_DEBUG, f"маршрутное задание: {self._mission}")
        self._log_message(LOG_DEBUG, f"состояние маршруте: {self._route}")
        # TODO реализовать контроль безопасности изменения направления
        target_point = self._route.next_point()
        current_point = self._position
        target_direction = self._calculate_bearing(current_point, target_point)
        if not self._mission or not self._position or not self._route:
            self._log_message(LOG_ERROR, f"Неизвестный маршрут или позиция! Остановка.")
            self._direction = 0
            self._speed = 0
            self._send_direction_to_consumers()
            self._send_speed_to_consumers()
            return

        if abs(direction - target_direction) > 1:  # Допустимое отклонение 1 градус
            self._log_message(LOG_ERROR, f"Некорректное направление! Запрошено: {direction}, ожидалось: {target_direction}")
            self._direction = target_direction
            self._send_direction_to_consumers()
            return  
        
        self._direction = direction
        self._send_direction_to_consumers()

    def _set_new_speed(self, speed: float):
        """ установка новой скорости """
        # TODO реализовать контроль безопасности изменения скорости
        current_limit = self._route.calculate_speed()

        if not self._mission or not self._position or not self._route:
            self._log_message(LOG_ERROR, f"Неизвестный маршрут или позиция! Остановка.")
            self._direction = 0
            self._speed = 0
            self._send_direction_to_consumers()
            self._send_speed_to_consumers()
            return
        
        if speed > current_limit:
            self._log_message(LOG_ERROR, f"Превышение скорости! Лимит: {current_limit}, запрошено: {speed}")
            self._speed = current_limit
        else:
            self._speed = speed
        
        self._send_speed_to_consumers()
        self._send_direction_to_consumers()
    
    def _calculate_bearing(self, start: GeoPoint, end: GeoPoint) -> float:
        delta_longitude = end.longitude - start.longitude
        x = math.sin(math.radians(delta_longitude)) * \
            math.cos(math.radians(end.latitude))
        y = math.cos(math.radians(start.latitude)) * math.sin(math.radians(end.latitude)) - \
            math.sin(math.radians(start.latitude)) * math.cos(math.radians(end.latitude)) * \
            math.cos(math.radians(delta_longitude))

        initial_bearing_rad = math.atan2(x, y)

        initial_bearing_deg = math.degrees(initial_bearing_rad)

        compass_bearing = (initial_bearing_deg + 360) % 360

        return compass_bearing


    def _send_speed_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем скорость получателям")
        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_speed",
                            parameters=self._speed
                            )
        security_q: Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_q.put(event_speed)

    def _send_direction_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем направление получателям")

        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        # отправка сообщения с желаемой скоростью
        event_direction = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_direction",
                            parameters=self._direction
                            )
        security_q: Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME) 
        security_q.put(event_direction)

    def _lock_cargo(self, _):
        self._log_message(LOG_INFO, "Блокировка грузового отсека")
        self._send_lock_cargo_to_consumers()

    def _release_cargo(self, _):
        if not self._mission or not self._position or not self._route:
            self._log_message(LOG_ERROR, "Неизвестный маршрут!")
            self._speed = 0
            self._direction = 0
            self._send_speed_to_consumers()
            self._send_direction_to_consumers()
            return
        if not self._route.route_finished:
            self._log_message(LOG_INFO, "Выгружать еще рано! ")
            return
        self._send_release_cargo_to_consumers()
        
    def _send_lock_cargo_to_consumers(self):
        self._log_message(LOG_DEBUG, "Отправляем команду на блокировку грузового отсека")
        event = Event(
            source=self.event_source_name,
            destination=CARGO_BAY_QUEUE_NAME,
            operation="lock_cargo",
            parameters=None
        )
        security_q : Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_q.put(event)

    def _send_release_cargo_to_consumers(self):
        self._log_message(LOG_DEBUG, "Отправляем команду на блокировку грузового отсека")
        event = Event(
            source=self.event_source_name,
            destination=CARGO_BAY_QUEUE_NAME,
            operation="release_cargo",
            parameters=None
        )
        security_q : Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_q.put(event)

# %% [markdown]
# Если у вас настроена и работает СУПА, установите в True значение переменной afcs_present

# %%
afcs_present = True

# %% [markdown]
# Поменяем идентификатор машинки для этого модуля

# %%
car_id = "m4"

# %% [markdown]
# В следующем блоке измените маршрут на ваш, его можно скопировать из модуля 2.
#
# Для проверки работы систем безопасности будут активированы киберпрепятствия
#
# ```python
# control_system.enable_critical_surprises()
# ```

# %%
# используем то же маршрутное задание, которое было в модуле 2
from time import sleep

from src.queues_dir import QueuesDirectory
from src.servos import Servos
from src.sitl import SITL
from src.cargo_bay import CargoBay
from src.mission_planner import MissionPlanner
from src.config import LOG_ERROR, LOG_INFO
from src.mission_planner_mqtt import MissionSender
from src.mission_planner import Mission
from src.sitl_mqtt import TelemetrySender
from src.system_wrapper import SystemComponentsContainer
from src.wpl_parser import WPLParser
from src.mission_type import GeoSpecificSpeedLimit


wpl_file = "kupchino_route.wpl"

parser = WPLParser(wpl_file)    
points = parser.parse()

# обновите скоростные ограничения для вашего маршрута!S
speed_limits = [
    GeoSpecificSpeedLimit(0, 60),
    GeoSpecificSpeedLimit(19, 100), 
    GeoSpecificSpeedLimit(26, 60)
]


home = points[0]
mission = Mission(home=home, waypoints=points,speed_limits=speed_limits, armed=True)

# каталог очередей для передачи сообщений между блоками
queues_dir = QueuesDirectory() 


# создание блоков передачи данных в СУПА
if afcs_present:
    mission_sender = MissionSender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)
    telemetry_sender = TelemetrySender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)

# создание основных функциональных блоков
mission_planner = MissionPlanner(
    queues_dir, afcs_present=afcs_present, mission=mission)

sitl = SITL(
    queues_dir=queues_dir, position=home,
    car_id=car_id, post_telemetry=afcs_present, log_level=LOG_ERROR)

communication_gateway = CommunicationGateway(
    queues_dir=queues_dir, log_level=LOG_ERROR)
control_system = ControlSystem(queues_dir=queues_dir, log_level=LOG_INFO)

navigation_system = NavigationSystem(
    queues_dir=queues_dir, log_level=LOG_ERROR)

servos = Servos(queues_dir=queues_dir, log_level=LOG_ERROR)
cargo_bay = CargoBay(queues_dir=queues_dir, log_level=LOG_INFO)

safety_block = SafetyBlock(queues_dir=queues_dir, log_level=LOG_INFO)

security_monitor = SecurityMonitor(queues_dir=queues_dir)
# сборка всех запускаемых блоков в одном "кузове"
system_components = SystemComponentsContainer(
    components=[
        mission_sender,
        telemetry_sender,
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system,
        safety_block,
        security_monitor
    ] if afcs_present else [
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system,
        safety_block,
        security_monitor
    ])

#################################
# АКТИВАЦИЯ КИБЕРПРЕПЯТСТВИЙ
control_system.enable_surprises()
#################################

# запуск всех блоков
system_components.start()

# ограничение поездки по времени
# в случае превышения времени выполнения ячейки на более чем 10 секунд от заданного, 
# допустимо перезапустить вычислительное ядро и повторно выполнить весь блокнот, штрафные очки за это не начисляются
# при условии, что повторный запуск закончился успешно
sleep(630)

# останавливаем все компоненты
system_components.stop()

# удалим все созданные компоненты
system_components.clean()
# Out:
# [ИНФО][QUEUES] создан каталог очередей
# [ИНФО][QUEUES] регистрируем очередь planner.mqtt
# [ИНФО][QUEUES] регистрируем очередь sitl.mqtt
# [ИНФО][QUEUES] регистрируем очередь planner
# [ИНФО][MISSION PLANNER] создана система планирования заданий
# [ИНФО][QUEUES] регистрируем очередь sitl
# [ИНФО][QUEUES] регистрируем очередь communication
# [ИНФО][QUEUES] регистрируем очередь control
# [ИНФО][CONTROL] создана система управления
# [ИНФО][QUEUES] регистрируем очередь navigation
# [ИНФО][QUEUES] регистрируем очередь servos
# [ИНФО][QUEUES] регистрируем очередь cargo
# [ИНФО][CARGO] создан компонент грузового отсека, отсек заблокирован
# [ИНФО][QUEUES] регистрируем очередь safety
# [ИНФО][SAFETY] создан ограничитель
# [ИНФО][QUEUES] регистрируем очередь security
# [ИНФО][SECURITY] создан монитор безопасности
# [ИНФО][SECURITY] изменение политик безопасности: [SecurityPolicy(source='communication', destination='control', operation='set_mission'), SecurityPolicy(source='communication', destination='safety', operation='set_mission'), SecurityPolicy(source='control', destination='safety', operation='set_speed'), SecurityPolicy(source='safety', destination='servos', operation='set_speed'), SecurityPolicy(source='control', destination='safety', operation='set_direction'), SecurityPolicy(source='safety', destination='servos', operation='set_direction'), SecurityPolicy(source='control', destination='safety', operation='release_cargo'), SecurityPolicy(source='safety', destination='cargo', operation='release_cargo'), SecurityPolicy(source='control', destination='safety', operation='lock_cargo'), SecurityPolicy(source='safety', destination='cargo', operation='lock_cargo'), SecurityPolicy(source='navigation', destination='safety', operation='position_update'), SecurityPolicy(source='navigation', destination='control', operation='position_update')]
# [ИНФО][MISSION PLANNER] старт системы планирования заданий
# [ИНФО][CARGO] старт блока грузового отсека
# [ИНФО][CONTROL] старт системы управления
# [ИНФО][SAFETY] старт ограничителя
# [ИНФО][SECURITY] старт блока грузового отсека
# [ИНФО][MISSION PLANNER] запрошена новая задача, отправляем получателям
# [ИНФО][MISSION PLANNER] новая задача отправлена в коммуникационный шлюз
# [ИНФО][CONTROL] установлена новая задача, начинаем следовать по маршруту, текущее время 13:17:30.054367
# [ИНФО][SAFETY] Блокировка грузового отсека
# [ИНФО][CONTROL] новая скорость 60 (была 0)
# [ИНФО][CONTROL] новое направление 194 (было 0)
# [ИНФО][CARGO] заблокировать грузовой отсек
# [ИНФО][CARGO] грузовой отсек заблокирован
# [ИНФО][SAFETY] текущие координаты: 59 47m 50.7012s N, 30 16m 22.1988s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 50.7012s N, 30 16m 22.1988s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 50.7012s N, 30 16m 22.1988s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 50.7012s N, 30 16m 22.1988s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 50.4404s N, 30 16m 22.0656s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 50.1796s N, 30 16m 21.9325s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 49.971s N, 30 16m 21.826s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 49.7102s N, 30 16m 21.6928s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 49.4494s N, 30 16m 21.5596s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 49.1887s N, 30 16m 21.4265s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 48.9279s N, 30 16m 21.2932s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 48.6671s N, 30 16m 21.16s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 48.4063s N, 30 16m 21.0267s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 48.1456s N, 30 16m 20.8934s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 47.8848s N, 30 16m 20.76s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 47.6241s N, 30 16m 20.6266s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 47.3633s N, 30 16m 20.4932s E
# [ИНФО][SAFETY] текущие координаты: 59 47m 47.1026s N, 30 16m 20.3597s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 322 (было 194)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 47m 46.8419s N, 30 16m 20.226s E
# [ОШИБКА][SAFETY] Некорректное направление! Запрошено: 322.71370009215207, ожидалось: 142.71370009215207
# [ИНФО][CONTROL] новое направление 319 (было 322)
# [ИНФО][SAFETY] текущие координаты: 59 47m 46.5812s N, 30 16m 20.0922s E
# [ОШИБКА][SAFETY] Некорректное направление! Запрошено: 319.4518756716417, ожидалось: 139.4518756716417
# [ИНФО][CONTROL] новое направление 315 (было 319)
# [ИНФО][SAFETY] текущие координаты: 59 47m 46.3205s N, 30 16m 19.958s E
# [ОШИБКА][SAFETY] Некорректное направление! Запрошено: 315.90644420831586, ожидалось: 135.90644420831586
# [ИНФО][SAFETY] текущие координаты: 59 47m 46.1063s N, 30 16m 20.2817s E
# [ОШИБКА][SAFETY] Некорректное направление! Запрошено: 315.3493185862129, ожидалось: 135.34931858621292
# [ИНФО][CONTROL] новое направление 314 (было 315)
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.9017s N, 30 16m 20.6291s E
# [ОШИБКА][SAFETY] Некорректное направление! Запрошено: 314.9816198157465, ожидалось: 134.9816198157465
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.7083s N, 30 16m 21.0009s E
# [ОШИБКА][SAFETY] Некорректное направление! Запрошено: 314.8869832797836, ожидалось: 134.88698327978358
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.5167s N, 30 16m 21.3765s E
# [ОШИБКА][SAFETY] Некорректное направление! Запрошено: 314.8319828901606, ожидалось: 134.8319828901606
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.3263s N, 30 16m 21.7544s E
# [ОШИБКА][SAFETY] Некорректное направление! Запрошено: 314.80810299089336, ожидалось: 134.80810299089336
# [ИНФО][SAFETY] текущие координаты: 59 47m 45.1363s N, 30 16m 22.133s E
# [ОШИБКА][SAFETY] Некорректное направление! Запрошено: 314.7906519005678, ожидалось: 134.7906519005678
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.9465s N, 30 16m 22.512s E
# [ОШИБКА][SAFETY] Некорректное направление! Запрошено: 314.776387955112, ожидалось: 134.776387955112
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.7567s N, 30 16m 22.8911s E
# [ОШИБКА][SAFETY] Некорректное направление! Запрошено: 314.76122617652, ожидалось: 134.76122617651998
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.567s N, 30 16m 23.2703s E
# [ОШИБКА][SAFETY] Некорректное направление! Запрошено: 314.7430340530575, ожидалось: 134.7430340530575
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.3773s N, 30 16m 23.6496s E
# [ОШИБКА][SAFETY] Некорректное направление! Запрошено: 314.7180657213929, ожидалось: 134.71806572139292
# [ИНФО][SAFETY] текущие координаты: 59 47m 44.1877s N, 30 16m 24.029s E
# [ОШИБКА][SAFETY] Некорректное направление! Запрошено: 314.67779079032493, ожидалось: 134.67779079032493
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.9981s N, 30 16m 24.4085s E
# [ОШИБКА][SAFETY] Некорректное направление! Запрошено: 314.58864509412774, ожидалось: 134.58864509412774
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 160 (была 60)
# [ИНФО][CONTROL] новое направление 82 (было 314)
# [ИНФО][SAFETY] сегмент пройден
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.8087s N, 30 16m 24.7882s E
# [ИНФО][CONTROL] новое направление 81 (было 82)
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.6572s N, 30 16m 25.0922s E
# [ИНФО][CONTROL] новое направление 80 (было 81)
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.4681s N, 30 16m 25.4726s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.4589s N, 30 16m 25.9724s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.497s N, 30 16m 26.5014s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.5388s N, 30 16m 27.0292s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 47m 43.5824s N, 30 16m 27.5565s E
# [ОШИБКА][SAFETY] Превышение скорости! Лимит: 60, запрошено: 160
# [ИНФО][SAFETY] текущие координаты: 59 47m 43
E
# [ИНФО][SAFETY] текущие координаты: 59 48m 58.5424s N, 30 22m 52.4626s E
# [ИНФО][SAFETY] текущие координаты: 59 48m 58.8061s N, 30 22m 52.5708s E
# [ИНФО][SAFETY] текущие координаты: 59 48m 59.0698s N, 30 22m 52.679s E
# [ИНФО][SAFETY] текущие координаты: 59 48m 59.3335s N, 30 22m 52.7873s E
# [ИНФО][SAFETY] текущие координаты: 59 48m 59.5972s N, 30 22m 52.8956s E
# [ИНФО][SAFETY] текущие координаты: 59 48m 59.8082s N, 30 22m 52.9822s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 0.0718885s N, 30 22m 53.0906s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 0.335575s N, 30 22m 53.1989s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 0.599256s N, 30 22m 53.3074s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 354 (было 11)
# [ИНФО][SAFETY] текущие координаты: 59 49m 0.86293s N, 30 22m 53.4159s E
# [ИНФО][CONTROL] новое направление 353 (было 354)
# [ИНФО][SAFETY] текущие координаты: 59 49m 1.12659s N, 30 22m 53.5245s E
# [ИНФО][CONTROL] новое направление 351 (было 353)
# [ИНФО][SAFETY] текущие координаты: 59 49m 1.39024s N, 30 22m 53.6333s E
# [ИНФО][CONTROL] новое направление 349 (было 351)
# [ИНФО][SAFETY] текущие координаты: 59 49m 1.65382s N, 30 22m 53.7427s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 1.92094s N, 30 22m 53.723s E
# [ИНФО][CONTROL] новое направление 348 (было 349)
# [ИНФО][SAFETY] текущие координаты: 59 49m 2.18841s N, 30 22m 53.6613s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 2.45499s N, 30 22m 53.586s E
# [ИНФО][CONTROL] новое направление 347 (было 348)
# [ИНФО][SAFETY] текущие координаты: 59 49m 2.72031s N, 30 22m 53.4949s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 2.98482s N, 30 22m 53.3948s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 3.24885s N, 30 22m 53.2898s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 3.51249s N, 30 22m 53.1809s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 3.77577s N, 30 22m 53.0687s E
# [ИНФО][CONTROL] новое направление 346 (было 347)
# [ИНФО][SAFETY] текущие координаты: 59 49m 4.03884s N, 30 22m 52.9546s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 4.30172s N, 30 22m 52.8387s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 49m 4.56419s N, 30 22m 52.7192s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 4.82637s N, 30 22m 52.5973s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 5.08793s N, 30 22m 52.4702s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 5.34968s N, 30 22m 52.3446s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 5.61142s N, 30 22m 52.219s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 5.87317s N, 30 22m 52.0934s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 6.13491s N, 30 22m 51.9678s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 6.39666s N, 30 22m 51.8422s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 6.6584s N, 30 22m 51.7167s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 6.92014s N, 30 22m 51.5911s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 7.18189s N, 30 22m 51.4655s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 7.44363s N, 30 22m 51.3399s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 7.65303s N, 30 22m 51.2394s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 7.91477s N, 30 22m 51.1138s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 8.17651s N, 30 22m 50.9882s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 8.43825s N, 30 22m 50.8625s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 8.69999s N, 30 22m 50.7369s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 8.96174s N, 30 22m 50.6113s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 9.22348s N, 30 22m 50.4857s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 9.48522s N, 30 22m 50.36s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 9.74696s N, 30 22m 50.2344s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 10.0087s N, 30 22m 50.1088s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 10.2704s N, 30 22m 49.9831s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 10.5322s N, 30 22m 49.8575s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 10.7939s N, 30 22m 49.7318s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 11.0556s N, 30 22m 49.6062s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 11.3174s N, 30 22m 49.4805s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 11.5791s N, 30 22m 49.3549s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 11.8409s N, 30 22m 49.2292s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 12.1026s N, 30 22m 49.1035s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 12.3643s N, 30 22m 48.9779s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 12.6261s N, 30 22m 48.8522s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 12.8878s N, 30 22m 48.7265s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 13.1495s N, 30 22m 48.6008s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 13.4113s N, 30 22m 48.4751s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 13.673s N, 30 22m 48.3494s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 13.9347s N, 30 22m 48.2237s E
# [ИНФО][SAFETY] текущие координаты: 59 49m
E
# [ИНФО][SAFETY] текущие координаты: 59 49m 36.0993s N, 30 22m 34.5587s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 36.3493s N, 30 22m 34.3602s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 36.5994s N, 30 22m 34.1617s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 36.8494s N, 30 22m 33.9631s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 37.0994s N, 30 22m 33.7645s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 37.3494s N, 30 22m 33.5659s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 37.5994s N, 30 22m 33.3672s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 37.8495s N, 30 22m 33.1686s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 38.0995s N, 30 22m 32.9698s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 38.3495s N, 30 22m 32.7711s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 38.5494s N, 30 22m 32.612s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 38.7994s N, 30 22m 32.4132s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 39.0494s N, 30 22m 32.2143s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 39.2993s N, 30 22m 32.0153s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 39.5493s N, 30 22m 31.8163s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 344 (было 338)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 49m 39.7992s N, 30 22m 31.6171s E
# [ИНФО][CONTROL] новое направление 345 (было 344)
# [ИНФО][SAFETY] текущие координаты: 59 49m 40.049s N, 30 22m 31.4177s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 40.2988s N, 30 22m 31.2179s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 40.5566s N, 30 22m 31.0656s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 40.8167s N, 30 22m 30.9271s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 41.0771s N, 30 22m 30.791s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 41.3377s N, 30 22m 30.6559s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 41.5983s N, 30 22m 30.521s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 41.8588s N, 30 22m 30.3862s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 42.1194s N, 30 22m 30.2514s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 42.38s N, 30 22m 30.1166s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 42.6406s N, 30 22m 29.9818s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 42.9012s N, 30 22m 29.8469s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 43.1618s N, 30 22m 29.7121s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 43.4223s N, 30 22m 29.5772s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 43.6829s N, 30 22m 29.4424s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 43.9435s N, 30 22m 29.3075s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 44.2041s N, 30 22m 29.1726s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 44.4646s N, 30 22m 29.0376s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 44.7252s N, 30 22m 28.9027s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 44.9858s N, 30 22m 28.7677s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 45.2463s N, 30 22m 28.6327s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 45.5069s N, 30 22m 28.4977s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 45.7674s N, 30 22m 28.3626s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 46.028s N, 30 22m 28.2275s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 46.2364s N, 30 22m 28.1194s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 46.4969s N, 30 22m 27.9842s E
# [ИНФО][SAFETY] текущие координаты: 59 49m 46.7574s N, 30 22m 27.8489s E
# [ИНФО][CONTROL] маршрут пройден, текущее время 13:27:31.425029
# [ИНФО][CONTROL] новая скорость 0.0 (была 60)
# [ИНФО][CONTROL] новое направление 0 (было 345)
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] текущие координаты: 59 49m 47.018s N, 30 22m 27.7135s E
# [ОШИБКА][SAFETY] ошибка обработки команд: 'NoneType' object has no attribute 'longitude'
# [ИНФО][CARGO] выгрузка
# [ИНФО][CARGO] груз оставлен
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден

# %% [markdown]
# Убедитесь, что
# 1. ваша машинка успешно прошла весь заданный маршрут
# 2. не превысила ограничения скорости
# 3. успешно доставила груз
#
# Если всё так - поздравляем, вы справились с заданием! Обязательно зафиксируйте все изменения в репозитории!

# %% [markdown]
# Мы будем признательны за обратную связь - любые комментарии, которые вы можете дать по итогам выполнения этого задания.
#
# Например,
#
# - было ли задание понятным по шкале 1..10 (1 - ничего не понятно, 10 - вопросов вообще не было, всё понятно)?
# - было ли задание интересным по шкале 1..10 (1 - скука смертная, 10 - лучшее, что вам пока встречалось на олимпиадах)?
# - что бы вы предложили изменить, чтобы сделает его более интересным?
# - по шкале 1..10 насколько сложным оно было для вас?
# - что было самым трудным в задании?
#
# Авторы наиболее развёрнутых и интересных комментариев получат особенный приз от Лаборатории Касперского!

# %% [markdown]
# Дополнительная информация о кибериммунной разработке
# - https://os.kaspersky.ru/cyber-immune-development/
# - https://github.com/sergey-sobolev/cyberimmune-systems/wiki/%D0%9A%D0%B8%D0%B1%D0%B5%D1%80%D0%B8%D0%BC%D0%BC%D1%83%D0%BD%D0%B8%D1%82%D0%B5%D1%82
# - канал в телеграм: https://t.me/learning_cyberimmunity
